# %%
# CALCOLO RGB PER CANZONI - VERSIONE CORRETTA
# !pip install -q git+https://github.com/huggingface/transformers
# !pip install -q qwen-omni-utils -U
# !pip install -q bitsandbytes -U
# !pip install -q accelerate
# !pip install -q pandas
# !pip install -q matplotlib # Aggiunto per la visualizzazione finale

# Import
from transformers import AutoModelForCausalLM, AutoTokenizer, BitsAndBytesConfig
import torch
import re
import gc
import csv
import pandas as pd
import matplotlib.pyplot as plt

model_name = "Qwen/Qwen3-4B"

# --- Preparazione della lista dei prompt dal CSV ---
# Percorso del file CSV di input con le descrizioni
csv_file = "/kaggle/input/dddddd/audio_analysis_full_folder (2).csv"
prompt_list = []
results_for_csv = []

try:
    # Leggiamo il CSV con pandas.
    df = pd.read_csv(csv_file, header=None)
    df.rename(columns={0: 'Song Name', 1: 'Description Type', 2: 'Description'}, inplace=True)

    # Riempi i valori NaN nella colonna 'Song Name' con il valore precedente
    df['Song Name'] = df['Song Name'].fillna(method='ffill')

    # Raggruppa i dati per Song Name e raccogli tutte le descrizioni
    for song_name, group in df.groupby('Song Name'):
        descriptions = {}
        for _, row in group.iterrows():
            desc_type = row['Description Type'].strip()
            desc_text = row['Description'].strip()
            descriptions[desc_type] = desc_text

        # Costruisci l'elenco delle descrizioni nell'ordine desiderato (Frammento 1-4, poi Totale)
        ordered_descriptions_content = []
        for i in range(1, 5): # Frammento 1 a 4
            content = descriptions.get(f'Fragment {i}', '')
            if content:
                ordered_descriptions_content.append({'label': f'Frammento {i}', 'content': content})

        # Aggiungi la descrizione totale per ultima
        overall_content = descriptions.get('Total', descriptions.get('Descrizione Totale', ''))
        if overall_content:
            ordered_descriptions_content.append({'label': 'Descrizione Totale', 'content': overall_content})

        # Assicurati di avere esattamente 5 descrizioni (4 frammenti + 1 totale)
        NUM_DESCRIPTIONS_EXPECTED = 5
        while len(ordered_descriptions_content) < NUM_DESCRIPTIONS_EXPECTED:
            ordered_descriptions_content.append({'label': 'Mancante', 'content': ''})

        # Costruisci il prompt per il modello
        prompt = f"Song Name: {song_name}\n\n"
        prompt += "Dati questi frammenti descrittivi di una canzone, valuta su una scala da 0 a 255 quanto ciascuno dei seguenti stati emotivi è evocato dalla descrizione:\n"
        prompt += "agitazione/movimento (R), calma (G), tristezza (B).\n\n"
        prompt += f"Restituisci **ESATTAMENTE {NUM_DESCRIPTIONS_EXPECTED} triple RGB COMPLETE**, una dopo l'altra, su una SINGOLA riga. \n"
        prompt += "Non includere nessuna spiegazione, numerazione, elenchi puntati o altro testo aggiuntivo. Non usare la modalità di pensiero ('thinking mode').\n"
        prompt += f"Inizia la riga con 'RGB:' e poi le {NUM_DESCRIPTIONS_EXPECTED} triple. Ogni tripla deve contenere esattamente tre valori separati da virgole.\n\n"
        prompt += "Ecco l'ESEMPIO ESATTO del formato desiderato (solo 5 triple complete, su una riga):\n"
        prompt += "RGB: (R1, G1, B1) (R2, G2, B2) (R3, G3, B3) (R4, G4, B4) (R5, G5, B5)\n\n"
        prompt += "Ecco i frammenti:\n"
        for item in ordered_descriptions_content:
            if item['content']:
                prompt += f"- {item['label']}: {item['content']}\n"
        
        prompt_list.append({'song_name': song_name, 'prompt_text': prompt})

except FileNotFoundError:
    print(f"Errore: Il file CSV '{csv_file}' non è stato trovato.")
    print("Assicurati che il file si trovi nel percorso specificato.")
    exit()
except Exception as e:
    print(f"Si è verificato un errore durante la lettura del CSV: {e}")
    print("Assicurati che le colonne siano presenti e accessibili con gli indici numerici corretti (0, 3, 4).")
    exit()

# --- Fine preparazione della lista dei prompt ---

# Parametri modello
compute_dtype = torch.float16

# Configurazione quantizzazione 4-bit
quant_config = BitsAndBytesConfig(
    load_in_4bit=True,
    bnb_4bit_quant_type="nf4",
    bnb_4bit_use_double_quant=True,
    bnb_4bit_compute_dtype=compute_dtype
)

# Caricamento tokenizer e modello
tokenizer = AutoTokenizer.from_pretrained(model_name, trust_remote_code=True)
model = AutoModelForCausalLM.from_pretrained(
    model_name,
    trust_remote_code=True,
    quantization_config=quant_config,
    device_map="auto",
    low_cpu_mem_usage=True,
    torch_dtype=compute_dtype
)

def extract_rgb_values(text):
    """
    Estrae i valori RGB dalla risposta del modello usando regex multiple per maggiore robustezza.
    Restituisce una lista di tuple (r, g, b).
    """
    # Pattern multipli per catturare diversi formati RGB
    patterns = [
        r"rgb\s*\(\s*(\d{1,3})\s*,\s*(\d{1,3})\s*,\s*(\d{1,3})\s*\)",  # rgb(r, g, b)
        r"\(\s*(\d{1,3})\s*,\s*(\d{1,3})\s*,\s*(\d{1,3})\s*\)",         # (r, g, b)
        r"(\d{1,3})\s*,\s*(\d{1,3})\s*,\s*(\d{1,3})",                   # r, g, b
        r"R:\s*(\d{1,3})\s*G:\s*(\d{1,3})\s*B:\s*(\d{1,3})",            # R: r G: g B: b
    ]
    
    found_matches = []
    
    for pattern in patterns:
        matches = re.findall(pattern, text, re.IGNORECASE)
        if matches:
            found_matches.extend(matches)
            break  # Usa il primo pattern che trova risultati
    
    # Se non trova nulla, prova a estrarre solo numeri consecutivi (fallback)
    if not found_matches:
        numbers = re.findall(r'\b(\d{1,3})\b', text)
        if len(numbers) >= 15:  # Almeno 15 numeri per 5 triple RGB
            # Raggruppa in triple di 3
            for i in range(0, min(15, len(numbers)), 3):
                if i + 2 < len(numbers):
                    found_matches.append((numbers[i], numbers[i+1], numbers[i+2]))
    
    return found_matches

def validate_and_clamp_rgb(rgb_tuple):
    """
    Valida e limita i valori RGB nell'intervallo 0-255.
    """
    try:
        r, g, b = int(rgb_tuple[0]), int(rgb_tuple[1]), int(rgb_tuple[2])
        r = max(0, min(255, r))
        g = max(0, min(255, g))
        b = max(0, min(255, b))
        return (r, g, b)
    except (ValueError, IndexError):
        return (0, 0, 0)  # Valore di default in caso di errore

# Loop sui prompt
for idx, entry in enumerate(prompt_list, start=1):
    song_name = entry['song_name']
    prompt_text = entry['prompt_text']

    print(f"\n=== Elaborazione canzone {idx}: {song_name} ===\n")

    chat = [{"role": "user", "content": prompt_text}]
    chat_text = tokenizer.apply_chat_template(chat, tokenize=False, add_generation_prompt=True, enable_thinking=False)

    inputs = tokenizer(chat_text, return_tensors="pt", truncation=True, max_length=2048)
    inputs = {k: v.to(model.device) for k, v in inputs.items()}

    outputs = model.generate(
        **inputs,
        max_new_tokens=256,
        do_sample=True,
        temperature=0.7,
        num_return_sequences=1,
    )

    response_text = tokenizer.decode(outputs[0][inputs["input_ids"].shape[1]:], skip_special_tokens=True).strip()
    print("Risposta generata dal modello:\n")
    print(response_text)
    print("\n" + "="*50)

    # --- PARSING RGB MIGLIORATO ---
    found_rgb_matches = extract_rgb_values(response_text)
    
    print(f"RGB matches trovati: {len(found_rgb_matches)}")
    print(f"Dettagli matches: {found_rgb_matches}")

    # Inizializza la riga per il CSV con il nome della canzone
    current_song_rgb_values = [song_name]

    # Popola esattamente 5 valori RGB (4 frammenti + Totale)
    NUM_EXPECTED_RGB = 5
    for i in range(NUM_EXPECTED_RGB):
        if i < len(found_rgb_matches):
            r, g, b = validate_and_clamp_rgb(found_rgb_matches[i])
            rgb_string = f'"rgb({r}, {g}, {b})"'  # Formato con virgolette per CSV
            current_song_rgb_values.append(rgb_string)
            print(f"Frammento {i+1}: {rgb_string}")
        else:
            # Valore di default se non c'è abbastanza dati
            default_rgb = '"rgb(100, 100, 100)"'  # Grigio neutro
            current_song_rgb_values.append(default_rgb)
            print(f"Frammento {i+1} (default): {default_rgb}")

    # Verifica che abbiamo esattamente 6 elementi (nome + 5 RGB)
    if len(current_song_rgb_values) != 6:
        print(f"ERRORE: Numero di elementi errato per {song_name}: {len(current_song_rgb_values)}")
        # Forza a 6 elementi
        while len(current_song_rgb_values) < 6:
            current_song_rgb_values.append('"rgb(100, 100, 100)"')
        current_song_rgb_values = current_song_rgb_values[:6]  # Taglia se troppo lungo

    results_for_csv.append(current_song_rgb_values)
    print(f"Riga CSV: {current_song_rgb_values}")

    # Pulisci la memoria GPU e CPU dopo ogni elaborazione
    del inputs, outputs
    torch.cuda.empty_cache()
    torch.cuda.ipc_collect()
    gc.collect()

# --- Salvataggio finale dei dati ---

print("\n--- Salvataggio dei colori RGB in CSV ---")
output_csv_file = "valutazione_rgb_segmenti.csv"
# L'header ora riflette esattamente il formato desiderato
csv_header = ['Song Name', 'Frammento 1', 'Frammento 2', 'Frammento 3', 'Frammento 4', 'Descrizione Totale']

try:
    with open(output_csv_file, mode='w', newline='', encoding='utf-8') as f:
        writer = csv.writer(f)
        writer.writerow(csv_header)
        writer.writerows(results_for_csv)
    
    print(f"Colori RGB salvati in '{output_csv_file}'")
    
    # Verifica del file salvato
    print(f"\nVerifica del file salvato:")
    with open(output_csv_file, 'r', encoding='utf-8') as f:
        lines = f.readlines()
        print(f"Numero di righe totali: {len(lines)}")
        print(f"Header: {lines[0].strip()}")
        if len(lines) > 1:
            print(f"Prima riga dati: {lines[1].strip()}")
        if len(lines) > 2:
            print(f"Seconda riga dati: {lines[2].strip()}")

except Exception as e:
    print(f"Errore durante il salvataggio del CSV: {e}")

print("\nProcessing complete. I valori RGB sono stati salvati nel file CSV.")

# --- Parte di visualizzazione (con matplotlib) ---
def parse_rgb_to_normalized_tuple(rgb_string):
    """
    Converte una stringa come "rgb(r, g, b)" o "rgb(r, g, b)" in una tupla di float (r, g, b)
    normalizzati nell'intervallo [0, 1] per matplotlib.
    """
    try:
        # Rimuovi virgolette se presenti
        rgb_string = rgb_string.strip('"\'')
        numeri = re.findall(r'\d+', rgb_string)
        if len(numeri) == 3:
            r = int(numeri[0]) / 255.0
            g = int(numeri[1]) / 255.0
            b = int(numeri[2]) / 255.0
            return (r, g, b)
        else:
            return (0.4, 0.4, 0.4)  # Grigio di default
    except (ValueError, IndexError):
        return (0.4, 0.4, 0.4)  # Grigio di default

def visualizza_colori_canzoni(nome_file_csv, max_canzoni=5):
    """
    Legge un file CSV e visualizza i colori per ogni canzone usando matplotlib.
    Mostra una finestra per ogni canzone, una alla volta.
    """
    try:
        with open(nome_file_csv, mode='r', newline='', encoding='utf-8') as file:
            lettore_csv = csv.reader(file)
            header = next(lettore_csv) # Salta l'intestazione

            print(f"\nSto per visualizzare i colori delle prime {max_canzoni} canzoni dal file CSV generato.")
            print("Chiudi ogni finestra per procedere alla successiva.")

            canzoni_visualizzate = 0
            for riga in lettore_csv:
                if not riga or len(riga) < 6:
                    continue

                if canzoni_visualizzate >= max_canzoni:
                    print(f"\nVisualizzazione completata. Modifica il parametro 'max_canzoni' per vederne di più.")
                    break

                nome_canzone = riga[0]
                # Prendiamo 5 stringhe di colore: 4 frammenti + Totale
                colori_stringa = riga[1:6] # Indici da 1 a 5 per 5 colonne

                colori = [parse_rgb_to_normalized_tuple(s) for s in colori_stringa]
                
                # Crea la figura e i subplot (1 riga, 5 colonne)
                fig, axes = plt.subplots(1, 5, figsize=(15, 3))
                fig.suptitle(f"Colori per la Canzone: {nome_canzone}", fontsize=14, fontweight='bold')

                # Definisce i titoli per ogni riquadro (4 frammenti + Totale)
                titoli = [f"Frammento {i+1}" for i in range(4)] + ["Descrizione Totale"]

                for ax, colore, titolo in zip(axes, colori, titoli):
                    ax.imshow([[colore]])
                    ax.set_title(titolo, fontsize=10)
                    ax.set_xticks([])
                    ax.set_yticks([])
                    # Aggiungi il valore RGB come testo
                    rgb_text = f"RGB({int(colore[0]*255)}, {int(colore[1]*255)}, {int(colore[2]*255)})"
                    ax.text(0.5, -0.1, rgb_text, ha='center', va='top', transform=ax.transAxes, fontsize=8)

                plt.tight_layout(rect=[0, 0.1, 1, 0.9])
                plt.show()

                canzoni_visualizzate += 1

    except FileNotFoundError:
        print(f"ERRORE: Il file '{nome_file_csv}' non è stato trovato.")
    except Exception as e:
        print(f"Si è verificato un errore durante la visualizzazione: {e}")

# --- ESECUZIONE DELLA VISUALIZZAZIONE ---
print(f"\n{'='*60}")
print("ESECUZIONE VISUALIZZAZIONE")
print(f"{'='*60}")

try:
    visualizza_colori_canzoni(output_csv_file, max_canzoni=3)
except Exception as e:
    print(f"Errore durante la visualizzazione: {e}")
# Out:
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
#   Building wheel for transformers (pyproject.toml) ... done
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 35.3/35.3 MB 49.1 MB/s eta 0:00:00:00:0100:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.0/67.0 MB 26.3 MB/s eta 0:00:00:00:0100:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 4.7 MB/s eta 0:00:000:00:0100:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.5 MB/s eta 0:00:000:00:0100:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 8.1 MB/s eta 0:00:000:00:0100:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 29.1 MB/s eta 0:00:00:00:0100:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 8.8 MB/s eta 0:00:000:00:0100:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 8.2 MB/s eta 0:00:000:00:0100:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 69.3 MB/s eta 0:00:00:00:0100:01
# /tmp/ipykernel_35/2891400135.py:32: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df['Song Name'] = df['Song Name'].fillna(method='ffill')
# tokenizer_config.json:   0%|          | 0.00/9.73k [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/2.78M [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/1.67M [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/11.4M [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/726 [00:00<?, ?B/s]
# 2025-06-21 09:57:19.633376: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1750499840.025908      35 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1750499840.146915      35 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# model.safetensors.index.json:   0%|          | 0.00/32.8k [00:00<?, ?B/s]
# Fetching 3 files:   0%|          | 0/3 [00:00<?, ?it/s]
# model-00003-of-00003.safetensors:   0%|          | 0.00/99.6M [00:00<?, ?B/s]
# model-00002-of-00003.safetensors:   0%|          | 0.00/3.99G [00:00<?, ?B/s]
# model-00001-of-00003.safetensors:   0%|          | 0.00/3.96G [00:00<?, ?B/s]
# Loading checkpoint shards:   0%|          | 0/3 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/239 [00:00<?, ?B/s]
# === Elaborazione canzone 1: 000002.mp3 ===
#
# Risposta generata dal modello:
#
# RGB: (220, 150, 30) (180, 120, 40) (200, 160, 50) (210, 140, 35) (190, 130, 45)
#
# ==================================================
# RGB matches trovati: 5
# Dettagli matches: [('220', '150', '30'), ('180', '120', '40'), ('200', '160', '50'), ('210', '140', '35'), ('190', '130', '45')]
# Frammento 1: "rgb(220, 150, 30)"
# Frammento 2: "rgb(180, 120, 40)"
# Frammento 3: "rgb(200, 160, 50)"
# Frammento 4: "rgb(210, 140, 35)"
# Frammento 5: "rgb(190, 130, 45)"
# Riga CSV: ['000002.mp3', '"rgb(220, 150, 30)"', '"rgb(180, 120, 40)"', '"rgb(200, 160, 50)"', '"rgb(210, 140, 35)"', '"rgb(190, 130, 45)"']
#
# === Elaborazione canzone 2: 000005.mp3 ===
#
# Risposta generata dal modello:
#
# RGB: (230, 165, 40) (210, 150, 30) (120, 80, 20) (180, 110, 30) (240, 120, 40)
#
# ==================================================
# RGB matches trovati: 5
# Dettagli matches: [('230', '165', '40'), ('210', '150', '30'), ('120', '80', '20'), ('180', '110', '30'), ('240', '120', '40')]
# Frammento 1: "rgb(230, 165, 40)"
# Frammento 2: "rgb(210, 150, 30)"
# Frammento 3: "rgb(120, 80, 20)"
# Frammento 4: "rgb(180, 110, 30)"
# Frammento 5: "rgb(240, 120, 40)"
# Riga CSV: ['000005.mp3', '"rgb(230, 165, 40)"', '"rgb(210, 150, 30)"', '"rgb(120, 80, 20)"', '"rgb(180, 110, 30)"', '"rgb(240, 120, 40)"']
#
# === Elaborazione canzone 3: 000010.mp3 ===
#
# Risposta generata dal modello:
#
# RGB: (220, 60, 30) (40, 40, 40) (140, 100, 60) (200, 80, 40) (230, 130, 60)
#
# ==================================================
# RGB matches trovati: 5
# Dettagli matches: [('220', '60', '30'), ('40', '40', '40'), ('140', '100', '60'), ('200', '80', '40'), ('230', '130', '60')]
# Frammento 1: "rgb(220, 60, 30)"
# Frammento 2: "rgb(40, 40, 40)"
# Frammento 3: "rgb(140, 100, 60)"
# Frammento 4: "rgb(200, 80, 40)"
# Frammento 5: "rgb(230, 130, 60)"
# Riga CSV: ['000010.mp3', '"rgb(220, 60, 30)"', '"rgb(40, 40, 40)"', '"rgb(140, 100, 60)"', '"rgb(200, 80, 40)"', '"rgb(230, 130, 60)"']
#
# === Elaborazione canzone 4: 000140.mp3 ===
#
# Risposta generata dal modello:
#
# RGB: (10, 150, 150) (10, 150, 150) (10, 150, 150) (10, 150, 150) (10, 150, 150)
#
# ==================================================
# RGB matches trovati: 5
# Dettagli matches: [('10', '150', '150'), ('10', '150', '150'), ('10', '150', '150'), ('10', '150', '150'), ('10', '150', '150')]
# Frammento 1: "rgb(10, 150, 150)"
# Frammento 2: "rgb(10, 150, 150)"
# Frammento 3: "rgb(10, 150, 150)"
# Frammento 4: "rgb(10, 150, 150)"
# Frammento 5: "rgb(10, 150, 150)"
# Riga CSV: ['000140.mp3', '"rgb(10, 150, 150)"', '"rgb(10, 150, 150)"', '"rgb(10, 150, 150)"', '"rgb(10, 150, 150)"', '"rgb(10, 150, 150)"']
#
# === Elaborazione canzone 5: 000141.mp3 ===
#
# Risposta generata dal modello:
#
# RGB: (120, 180, 60) (60, 100, 120) (150, 100, 100) (80, 60, 100) (140, 160, 120)
#
# ==================================================
# RGB matches trovati: 5
# Dettagli matches: [('120', '180', '60'), ('60', '100', '120'), ('150', '100', '100'), ('80', '60', '100'), ('140', '160', '120')]
# Frammento 1: "rgb(120, 180, 60)"
# Frammento 2: "rgb(60, 100, 120)"
# Frammento 3: "rgb(150, 100, 100)"
# Frammento 4: "rgb(80, 60, 100)"
# Frammento 5: "rgb(140, 160, 120)"
# Riga CSV: ['000141.mp3', '"rgb(120, 180, 60)"', '"rgb(60, 100, 120)"', '"rgb(150, 100, 100)"', '"rgb(80, 60, 100)"', '"rgb(140, 160, 120)"']
#
# === Elaborazione canzone 6: 000148.mp3 ===
#
# Risposta generata dal modello:
#
# RGB: (255, 30, 30) (255, 150, 30) (255, 30, 150) (30, 30, 255) (255, 30, 30)
#
# ==================================================
# RGB matches trovati: 5
# Dettagli matches: [('255', '30', '30'), ('255', '150', '30'), ('255', '30', '150'), ('30', '30', '255'), ('255', '30', '30')]
# Frammento 1: "rgb(255, 30, 30)"
# Frammento 2: "rgb(255, 150, 30)"
# Frammento 3: "rgb(255, 30, 150)"
# Frammento 4: "rgb(30, 30, 255)"
# Frammento 5: "rgb(255, 30, 30)"
# Riga CSV: ['000148.mp3', '"rgb(255, 30, 30)"', '"rgb(255, 150, 30)"', '"rgb(255, 30, 150)"', '"rgb(30, 30, 255)"', '"rgb(255, 30, 30)"']
#
# === Elaborazione canzone 7: 000182.mp3 ===
#
# Risposta generata dal modello:
#
# RGB: (255, 100, 0) (255, 150, 0) (255, 100, 0) (255, 150, 0) (255, 150, 0)
#
# ==================================================
# RGB matches trovati: 5
# Dettagli matches: [('255', '100', '0'), ('255', '150', '0'), ('255', '100', '0'), ('255', '150', '0'), ('255', '150', '0')]
# Frammento 1: "rgb(255, 100, 0)"
# Frammento 2: "rgb(255, 150, 0)"
# Frammento 3: "rgb(255, 100, 0)"
# Frammento 4: "rgb(255, 150, 0)"
# Frammento 5: "rgb(255, 150, 0)"
# Riga CSV: ['000182.mp3', '"rgb(255, 100, 0)"', '"rgb(255, 150, 0)"', '"rgb(255, 100, 0)"', '"rgb(255, 150, 0)"', '"rgb(255, 150, 0)"']
#
# === Elaborazione canzone 8: 000190.mp3 ===
#
# Risposta generata dal modello:
#
# RGB: (10, 15, 10) (180, 200, 160) (80, 120, 100) (200, 180, 80) (150, 190, 120)
#
# ==================================================
# RGB matches trovati: 5
# Dettagli matches: [('10', '15', '10'), ('180', '200', '160'), ('80', '120', '100'), ('200', '180', '80'), ('150', '190', '120')]
# Frammento 1: "rgb(10, 15, 10)"
# Frammento 2: "rgb(180, 200, 160)"
# Frammento 3: "rgb(80, 120, 100)"
# Frammento 4: "rgb(200, 180, 80)"
# Frammento 5: "rgb(150, 190, 120)"
# Riga CSV: ['000190.mp3', '"rgb(10, 15, 10)"', '"rgb(180, 200, 160)"', '"rgb(80, 120, 100)"', '"rgb(200, 180, 80)"', '"rgb(150, 190, 120)"']
#
# === Elaborazione canzone 9: 000193.mp3 ===
#
# Risposta generata dal modello:
#
# RGB: (100, 20, 30) (120, 60, 40) (80, 40, 60) (140, 80, 20) (160, 100, 50)
#
# ==================================================
# RGB matches trovati: 5
# Dettagli matches: [('100', '20', '30'), ('120', '60', '40'), ('80', '40', '60'), ('140', '80', '20'), ('160', '100', '50')]
# Frammento 1: "rgb(100, 20, 30)"
# Frammento 2: "rgb(120, 60, 40)"
# Frammento 3: "rgb(80, 40, 60)"
# Frammento 4: "rgb(140, 80, 20)"
# Frammento 5: "rgb(160, 100, 50)"
# Riga CSV: ['000193.mp3', '"rgb(100, 20, 30)"', '"rgb(120, 60, 40)"', '"rgb(80, 40, 60)"', '"rgb(140, 80, 20)"', '"rgb(160, 100, 50)"']
#
# === Elaborazione canzone 10: 000194.mp3 ===
#
# Risposta generata dal modello:
#
# RGB: (100, 150, 120) (120, 140, 110) (130, 145, 105) (110, 135, 95) (125, 140, 90)
#
# ==================================================
# RGB matches trovati: 5
# Dettagli matches: [('100', '150', '120'), ('120', '140', '110'), ('130', '145', '105'), ('110', '135', '95'), ('125', '140', '90')]
# Frammento 1: "rgb(100, 150, 120)"
# Frammento 2: "rgb(120, 140, 110)"
# Frammento 3: "rgb(130, 145, 105)"
# Frammento 4: "rgb(110, 135, 95)"
# Frammento 5: "rgb(125, 140, 90)"
# Riga CSV: ['000194.mp3', '"rgb(100, 150, 120)"', '"rgb(120, 140, 110)"', '"rgb(130, 145, 105)"', '"rgb(110, 135, 95)"', '"rgb(125, 140, 90)"']
#
# === Elaborazione canzone 11: 000197.mp3 ===
#
# Risposta generata dal modello:
#
# RGB: (10, 20, 60) (15, 25, 65) (20, 30, 70) (25, 35, 75) (30, 40, 80)
#
# ==================================================
# RGB matches trovati: 5
# Dettagli matches: [('10', '20', '60'), ('15', '25', '65'), ('20', '30', '70'), ('25', '35', '75'), ('30', '40', '80')]
# Frammento 1: "rgb(10, 20, 60)"
# Frammento 2: "rgb(15, 25, 65)"
# Frammento 3: "rgb(20, 30, 70)"
# Frammento 4: "rgb(25, 35, 75)"
# Frammento 5: "rgb(30, 40, 80)"
# Riga CSV: ['000197.mp3', '"rgb(10, 20, 60)"', '"rgb(15, 25, 65)"', '"rgb(20, 30, 70)"', '"rgb(25, 35, 75)"', '"rgb(30, 40, 80)"']
#
# === Elaborazione canzone 12: 000200.mp3 ===
#
# Risposta generata dal modello:
#
# RGB: (100, 150, 100) (50, 100, 50) (120, 130, 110) (70, 110, 60) (90, 140, 80)
#
# ==================================================
# RGB matches trovati: 5
# Dettagli matches: [('100', '150', '100'), ('50', '100', '50'), ('120', '130', '110'), ('70', '110', '60'), ('90', '140', '80')]
# Frammento 1: "rgb(100, 150, 100)"
# Frammento 2: "rgb(50, 100, 50)"
# Frammento 3: "rgb(120, 130, 110)"
# Frammento 4: "rgb(70, 110, 60)"
# Frammento 5: "rgb(90, 140, 80)"
# Riga CSV: ['000200.mp3', '"rgb(100, 150, 100)"', '"rgb(50, 100, 50)"', '"rgb(120, 130, 110)"', '"rgb(70, 110, 60)"', '"rgb(90, 140, 80)"']
#
# === Elaborazione canzone 13: 000203.mp3 ===
#
# Risposta generata dal modello:
#
# RGB: (120, 180, 60) (150, 170, 50) (160, 180, 40) (140, 170, 55) (130, 160, 65)
#
# ==================================================
# RGB matches trovati: 5
# Dettagli matches: [('120', '180', '60'), ('150', '170', '50'), ('160', '180', '40'), ('140', '170', '55'), ('130', '160', '65')]
# Frammento 1: "rgb(120, 180, 60)"
# Frammento 2: "rgb(150, 170, 50)"
# Frammento 3: "rgb(160, 180, 40)"
# Frammento 4: "rgb(140, 170, 55)"
# Frammento 5: "rgb(130, 160, 65)"
# Riga CSV: ['000203.mp3', '"rgb(120, 180, 60)"', '"rgb(150, 170, 50)"', '"rgb(160, 180, 40)"', '"rgb(140, 170, 55)"', '"rgb(130, 160, 65)"']
#
# === Elaborazione canzone 14: 000204.mp3 ===
#
# Risposta generata dal modello:
#
# RGB: (10, 150, 150) (30, 130, 120) (50, 120, 90) (20, 140, 110) (40, 130, 100)
#
# ==================================================
# RGB matches trovati: 5
# Dettagli matches: [('10', '150', '150'), ('30', '130', '120'), ('50', '120', '90'), ('20', '140', '110'), ('40', '130', '100')]
# Frammento 1: "rgb(10, 150, 150)"
# Frammento 2: "rgb(30, 130, 120)"
# Frammento 3: "rgb(50, 120, 90)"
# Frammento 4: "rgb(20, 140, 110)"
# Frammento 5: "rgb(40, 130, 100)"
# Riga CSV: ['000204.mp3', '"rgb(10, 150, 150)"', '"rgb(30, 130, 120)"', '"rgb(50, 120, 90)"', '"rgb(20, 140, 110)"', '"rgb(40, 130, 100)"']
#
# === Elaborazione canzone 15: 000207.mp3 ===
#
# Risposta generata dal modello:
#
# RGB: (10, 150, 150) (180, 180, 100) (100, 100, 100) (200, 100, 50) (150, 150, 50)
#
# ==================================================
# RGB matches trovati: 5
# Dettagli matches: [('10', '150', '150'), ('180', '180', '100'), ('100', '100', '100'), ('200', '100', '50'), ('150', '150', '50')]
# Frammento 1: "rgb(10, 150, 150)"
# Frammento 2: "rgb(180, 180, 100)"
# Frammento 3: "rgb(100, 100, 100)"
# Frammento 4: "rgb(200, 100, 50)"
# Frammento 5: "rgb(150, 150, 50)"
# Riga CSV: ['000207.mp3', '"rgb(10, 150, 150)"', '"rgb(180, 180, 100)"', '"rgb(100, 100, 100)"', '"rgb(200, 100, 50)"', '"rgb(150, 150, 50)"']
#
# === Elaborazione canzone 16: 000210.mp3 ===
#
# Risposta generata dal modello:
#
# RGB: (120, 160, 80) (110, 140, 70) (130, 150, 60) (100, 130, 60) (125, 155, 75)
#
# ==================================================
# RGB matches trovati: 5
# Dettagli matches: [('120', '160', '80'), ('110', '140', '70'), ('130', '150', '60'), ('100', '130', '60'), ('125', '155', '75')]
# Frammento 1: "rgb(120, 160, 80)"
# Frammento 2: "rgb(110, 140, 70)"
# Frammento 3: "rgb(130, 150, 60)"
# Frammento 4: "rgb(100, 130, 60)"
# Frammento 5: "rgb(125, 155, 75)"
# Riga CSV: ['000210.mp3', '"rgb(120, 160, 80)"', '"rgb(110, 140, 70)"', '"rgb(130, 150, 60)"', '"rgb(100, 130, 60)"', '"rgb(125, 155, 75)"']
#
# === Elaborazione canzone 17: 000211.mp3 ===
#
# Risposta generata dal modello:
#
# RGB: (120, 150, 100) (130, 140, 90) (110, 130, 80) (125, 135, 95) (100, 120, 70)
#
# ==================================================
# RGB matches trovati: 5
# Dettagli matches: [('120', '150', '100'), ('130', '140', '90'), ('110', '130', '80'), ('125', '135', '95'), ('100', '120', '70')]
# Frammento 1: "rgb(120, 150, 100)"
# Frammento 2: "rgb(130, 140, 90)"
# Frammento 3: "rgb(110, 130, 80)"
# Frammento 4: "rgb(125, 135, 95)"
# Frammento 5: "rgb(100, 120, 70)"
# Riga CSV: ['000211.mp3', '"rgb(120, 150, 100)"', '"rgb(130, 140, 90)"', '"rgb(110, 130, 80)"', '"rgb(125, 135, 95)"', '"rgb(100, 120, 70)"']
#
# === Elaborazione canzone 18: 000212.mp3 ===
#
# Risposta generata dal modello:
#
# RGB: (170, 180, 140) (190, 160, 110) (150, 160, 100) (70, 100, 80) (140, 160, 110)
#
# ==================================================
# RGB matches trovati: 5
# Dettagli matches: [('170', '180', '140'), ('190', '160', '110'), ('150', '160', '100'), ('70', '100', '80'), ('140', '160', '110')]
# Frammento 1: "rgb(170, 180, 140)"
# Frammento 2: "rgb(190, 160, 110)"
# Frammento 3: "rgb(150, 160, 100)"
# Frammento 4: "rgb(70, 100, 80)"
# Frammento 5: "rgb(140, 160, 110)"
# Riga CSV: ['000212.mp3', '"rgb(170, 180, 140)"', '"rgb(190, 160, 110)"', '"rgb(150, 160, 100)"', '"rgb(70, 100, 80)"', '"rgb(140, 160, 110)"']
#
# === Elaborazione canzone 19: 000213.mp3 ===
#
# Risposta generata dal modello:
#
# RGB: (180, 100, 40) (50, 100, 100) (150, 150, 100) (50, 50, 100) (100, 100, 100)
#
# ==================================================
# RGB matches trovati: 5
# Dettagli matches: [('180', '100', '40'), ('50', '100', '100'), ('150', '150', '100'), ('50', '50', '100'), ('100', '100', '100')]
# Frammento 1: "rgb(180, 100, 40)"
# Frammento 2: "rgb(50, 100, 100)"
# Frammento 3: "rgb(150, 150, 100)"
# Frammento 4: "rgb(50, 50, 100)"
# Frammento 5: "rgb(100, 100, 100)"
# Riga CSV: ['000213.mp3', '"rgb(180, 100, 40)"', '"rgb(50, 100, 100)"', '"rgb(150, 150, 100)"', '"rgb(50, 50, 100)"', '"rgb(100, 100, 100)"']
#
# === Elaborazione canzone 20: 000255.mp3 ===
#
# Risposta generata dal modello:
#
# RGB: (120, 160, 100) (180, 100, 60) (200, 150, 80) (190, 140, 50) (180, 160, 100)
#
# ==================================================
# RGB matches trovati: 5
# Dettagli matches: [('120', '160', '100'), ('180', '100', '60'), ('200', '150', '80'), ('190', '140', '50'), ('180', '160', '100')]
# Frammento 1: "rgb(120, 160, 100)"
# Frammento 2: "rgb(180, 100, 60)"
# Frammento 3: "rgb(200, 150, 80)"
# Frammento 4: "rgb(190, 140, 50)"
# Frammento 5: "rgb(180, 160, 100)"
# Riga CSV: ['000255.mp3', '"rgb(120, 160, 100)"', '"rgb(180, 100, 60)"', '"rgb(200, 150, 80)"', '"rgb(190, 140, 50)"', '"rgb(180, 160, 100)"']
#
# === Elaborazione canzone 21: 000256.mp3 ===
#
# Risposta generata dal modello:
#
# RGB: (230, 60, 30) (210, 70, 30) (240, 100, 30) (220, 80, 30) (230, 50, 30)
#
# ==================================================
# RGB matches trovati: 5
# Dettagli matches: [('230', '60', '30'), ('210', '70', '30'), ('240', '100', '30'), ('220', '80', '30'), ('230', '50', '30')]
# Frammento 1: "rgb(230, 60, 30)"
# Frammento 2: "rgb(210, 70, 30)"
# Frammento 3: "rgb(240, 100, 30)"
# Frammento 4: "rgb(220, 80, 30)"
# Frammento 5: "rgb(230, 50, 30)"
# Riga CSV: ['000256.mp3', '"rgb(230, 60, 30)"', '"rgb(210, 70, 30)"', '"rgb(240, 100, 30)"', '"rgb(220, 80, 30)"', '"rgb(230, 50, 30)"']
#
# === Elaborazione canzone 22: 000368.mp3 ===
#
# Risposta generata dal modello:
#
# RGB: (200, 50, 50) (100, 150, 50) (200, 100, 100) (150, 50, 100) (180, 60, 60)
#
# ==================================================
# RGB matches trovati: 5
# Dettagli matches: [('200', '50', '50'), ('100', '150', '50'), ('200', '100', '100'), ('150', '50', '100'), ('180', '60', '60')]
# Frammento 1: "rgb(200, 50, 50)"
# Frammento 2: "rgb(100, 150, 50)"
# Frammento 3: "rgb(200, 100, 100)"
# Frammento 4: "rgb(150, 50, 100)"
# Frammento 5: "rgb(180, 60, 60)"
# Riga CSV: ['000368.mp3', '"rgb(200, 50, 50)"', '"rgb(100, 150, 50)"', '"rgb(200, 100, 100)"', '"rgb(150, 50, 100)"', '"rgb(180, 60, 60)"']
#
# === Elaborazione canzone 23: 000424.mp3 ===
#
# Risposta generata dal modello:
#
# RGB: (135, 150, 100) (180, 190, 120) (30, 40, 60) (50, 70, 90) (160, 170, 140)
#
# ==================================================
# RGB matches trovati: 5
# Dettagli matches: [('135', '150', '100'), ('180', '190', '120'), ('30', '40', '60'), ('50', '70', '90'), ('160', '170', '140')]
# Frammento 1: "rgb(135, 150, 100)"
# Frammento 2: "rgb(180, 190, 120)"
# Frammento 3: "rgb(30, 40, 60)"
# Frammento 4: "rgb(50, 70, 90)"
# Frammento 5: "rgb(160, 170, 140)"
# Riga CSV: ['000424.mp3', '"rgb(135, 150, 100)"', '"rgb(180, 190, 120)"', '"rgb(30, 40, 60)"', '"rgb(50, 70, 90)"', '"rgb(160, 170, 140)"']
#
# === Elaborazione canzone 24: 000459.mp3 ===
#
# Risposta generata dal modello:
#
# RGB: (230, 100, 40) (210, 130, 60) (180, 80, 20) (200, 150, 60) (220, 120, 40)
#
# ==================================================
# RGB matches trovati: 5
# Dettagli matches: [('230', '100', '40'), ('210', '130', '60'), ('180', '80', '20'), ('200', '150', '60'), ('220', '120', '40')]
# Frammento 1: "rgb(230, 100, 40)"
# Frammento 2: "rgb(210, 130, 60)"
# Frammento 3: "rgb(180, 80, 20)"
# Frammento 4: "rgb(200, 150, 60)"
# Frammento 5: "rgb(220, 120, 40)"
# Riga CSV: ['000459.mp3', '"rgb(230, 100, 40)"', '"rgb(210, 130, 60)"', '"rgb(180, 80, 20)"', '"rgb(200, 150, 60)"', '"rgb(220, 120, 40)"']
#
# === Elaborazione canzone 25: 000534.mp3 ===
#
# Risposta generata dal modello:
#
# RGB: (120, 180, 60) (30, 50, 10) (150, 170, 60) (140, 160, 50) (120, 170, 50)
#
# ==================================================
# RGB matches trovati: 5
# Dettagli matches: [('120', '180', '60'), ('30', '50', '10'), ('150', '170', '60'), ('140', '160', '50'), ('120', '170', '50')]
# Frammento 1: "rgb(120, 180, 60)"
# Frammento 2: "rgb(30, 50, 10)"
# Frammento 3: "rgb(150, 170, 60)"
# Frammento 4: "rgb(140, 160, 50)"
# Frammento 5: "rgb(120, 170, 50)"
# Riga CSV: ['000534.mp3', '"rgb(120, 180, 60)"', '"rgb(30, 50, 10)"', '"rgb(150, 170, 60)"', '"rgb(140, 160, 50)"', '"rgb(120, 170, 50)"']
#
# === Elaborazione canzone 26: 000540.mp3 ===
#
# Risposta generata dal modello:
#
# RGB: (140, 180, 100) (60, 80, 120) (160, 160, 140) (120, 100, 80) (180, 160, 140)
#
# ==================================================
# RGB matches trovati: 5
# Dettagli matches: [('140', '180', '100'), ('60', '80', '120'), ('160', '160', '140'), ('120', '100', '80'), ('180', '160', '140')]
# Frammento 1: "rgb(140, 180, 100)"
# Frammento 2: "rgb(60, 80, 120)"
# Frammento 3: "rgb(160, 160, 140)"
# Frammento 4: "rgb(120, 100, 80)"
# Frammento 5: "rgb(180, 160, 140)"
# Riga CSV: ['000540.mp3', '"rgb(140, 180, 100)"', '"rgb(60, 80, 120)"', '"rgb(160, 160, 140)"', '"rgb(120, 100, 80)"', '"rgb(180, 160, 140)"']
#
# === Elaborazione canzone 27: 000546.mp3 ===
#
# Risposta generata dal modello:
#
# RGB: (120, 140, 100) (180, 160, 120) (80, 60, 40) (140, 100, 60) (160, 140, 120)
#
# ==================================================
# RGB matches trovati: 5
# Dettagli matches: [('120', '140', '100'), ('180', '160', '120'), ('80', '60', '40'), ('140', '100', '60'), ('160', '140', '120')]
# Frammento 1: "rgb(120, 140, 100)"
# Frammento 2: "rgb(180, 160, 120)"
# Frammento 3: "rgb(80, 60, 40)"
# Frammento 4: "rgb(140, 100, 60)"
# Frammento 5: "rgb(160, 140, 120)"
# Riga CSV: ['000546.mp3', '"rgb(120, 140, 100)"', '"rgb(180, 160, 120)"', '"rgb(80, 60, 40)"', '"rgb(140, 100, 60)"', '"rgb(160, 140, 120)"']
#
# === Elaborazione canzone 28: 000574.mp3 ===
#
# Risposta generata dal modello:
#
# RGB: (255, 100, 0) (0, 100, 0) (255, 100, 0) (255, 0, 0) (255, 100, 0)
#
# ==================================================
# RGB matches trovati: 5
# Dettagli matches: [('255', '100', '0'), ('0', '100', '0'), ('255', '100', '0'), ('255', '0', '0'), ('255', '100', '0')]
# Frammento 1: "rgb(255, 100, 0)"
# Frammento 2: "rgb(0, 100, 0)"
# Frammento 3: "rgb(255, 100, 0)"
# Frammento 4: "rgb(255, 0, 0)"
# Frammento 5: "rgb(255, 100, 0)"
# Riga CSV: ['000574.mp3', '"rgb(255, 100, 0)"', '"rgb(0, 100, 0)"', '"rgb(255, 100, 0)"', '"rgb(255, 0, 0)"', '"rgb(255, 100, 0)"']
#
# === Elaborazione canzone 29: 000602.mp3 ===
#
# Risposta generata dal modello:
#
# RGB: (100, 180, 100) (120, 170, 90) (110, 175, 95) (105, 178, 92) (80, 160, 85)
#
# ==================================================
# RGB matches trovati: 5
# Dettagli matches: [('100', '180', '100'), ('120', '170', '90'), ('110', '175', '95'), ('105', '178', '92'), ('80', '160', '85')]
# Frammento 1: "rgb(100, 180, 100)"
# Frammento 2: "rgb(120, 170, 90)"
# Frammento 3: "rgb(110, 175, 95)"
# Frammento 4: "rgb(105, 178, 92)"
# Frammento 5: "rgb(80, 160, 85)"
# Riga CSV: ['000602.mp3', '"rgb(100, 180, 100)"', '"rgb(120, 170, 90)"', '"rgb(110, 175, 95)"', '"rgb(105, 178, 92)"', '"rgb(80, 160, 85)"']
#
# === Elaborazione canzone 30: 000615.mp3 ===
#
# Risposta generata dal modello:
#
# RGB: (100, 150, 50) (180, 190, 120) (140, 160, 80) (50, 100, 150) (120, 160, 100)
#
# ==================================================
# RGB matches trovati: 5
# Dettagli matches: [('100', '150', '50'), ('180', '190', '120'), ('140', '160', '80'), ('50', '100', '150'), ('120', '160', '100')]
# Frammento 1: "rgb(100, 150, 50)"
# Frammento 2: "rgb(180, 190, 120)"
# Frammento 3: "rgb(140, 160, 80)"
# Frammento 4: "rgb(50, 100, 150)"
# Frammento 5: "rgb(120, 160, 100)"
# Riga CSV: ['000615.mp3', '"rgb(100, 150, 50)"', '"rgb(180, 190, 120)"', '"rgb(140, 160, 80)"', '"rgb(50, 100, 150)"', '"rgb(120, 160, 100)"']
#
# === Elaborazione canzone 31: 000620.mp3 ===
#
# Risposta generata dal modello:
#
# RGB: (135, 190, 100) (60, 50, 80) (170, 80, 120) (30, 10, 40) (150, 180, 100)
#
# ==================================================
# RGB matches trovati: 5
# Dettagli matches: [('135', '190', '100'), ('60', '50', '80'), ('170', '80', '120'), ('30', '10', '40'), ('150', '180', '100')]
# Frammento 1: "rgb(135, 190, 100)"
# Frammento 2: "rgb(60, 50, 80)"
# Frammento 3: "rgb(170, 80, 120)"
# Frammento 4: "rgb(30, 10, 40)"
# Frammento 5: "rgb(150, 180, 100)"
# Riga CSV: ['000620.mp3', '"rgb(135, 190, 100)"', '"rgb(60, 50, 80)"', '"rgb(170, 80, 120)"', '"rgb(30, 10, 40)"', '"rgb(150, 180, 100)"']
#
# === Elaborazione canzone 32: 000621.mp3 ===
#
# Risposta generata dal modello:
#
# RGB: (100, 150, 100) (120, 160, 90) (200, 100, 50) (80, 180, 120) (140, 160, 110)
#
# ==================================================
# RGB matches trovati: 5
# Dettagli matches: [('100', '150', '100'), ('120', '160', '90'), ('200', '100', '50'), ('80', '180', '120'), ('140', '160', '110')]
# Frammento 1: "rgb(100, 150, 100)"
# Frammento 2: "rgb(120, 160, 90)"
# Frammento 3: "rgb(200, 100, 50)"
# Frammento 4: "rgb(80, 180, 120)"
# Frammento 5: "rgb(140, 160, 110)"
# Riga CSV: ['000621.mp3', '"rgb(100, 150, 100)"', '"rgb(120, 160, 90)"', '"rgb(200, 100, 50)"', '"rgb(80, 180, 120)"', '"rgb(140, 160, 110)"']
#
# === Elaborazione canzone 33: 000625.mp3 ===
#
# Risposta generata dal modello:
#
# RGB: (170, 100, 50) (30, 30, 30) (100, 100, 100) (50, 50, 50) (150, 100, 50)
#
# ==================================================
# RGB matches trovati: 5
# Dettagli matches: [('170', '100', '50'), ('30', '30', '30'), ('100', '100', '100'), ('50', '50', '50'), ('150', '100', '50')]
# Frammento 1: "rgb(170, 100, 50)"
# Frammento 2: "rgb(30, 30, 30)"
# Frammento 3: "rgb(100, 100, 100)"
# Frammento 4: "rgb(50, 50, 50)"
# Frammento 5: "rgb(150, 100, 50)"
# Riga CSV: ['000625.mp3', '"rgb(170, 100, 50)"', '"rgb(30, 30, 30)"', '"rgb(100, 100, 100)"', '"rgb(50, 50, 50)"', '"rgb(150, 100, 50)"']
#
# === Elaborazione canzone 34: 000666.mp3 ===
#
# Risposta generata dal modello:
#
# RGB: (190, 50, 50) (140, 120, 60) (200, 80, 60) (180, 100, 50) (220, 130, 50)
#
# ==================================================
# RGB matches trovati: 5
# Dettagli matches: [('190', '50', '50'), ('140', '120', '60'), ('200', '80', '60'), ('180', '100', '50'), ('220', '130', '50')]
# Frammento 1: "rgb(190, 50, 50)"
# Frammento 2: "rgb(140, 120, 60)"
# Frammento 3: "rgb(200, 80, 60)"
# Frammento 4: "rgb(180, 100, 50)"
# Frammento 5: "rgb(220, 130, 50)"
# Riga CSV: ['000666.mp3', '"rgb(190, 50, 50)"', '"rgb(140, 120, 60)"', '"rgb(200, 80, 60)"', '"rgb(180, 100, 50)"', '"rgb(220, 130, 50)"']
#
# === Elaborazione canzone 35: 000667.mp3 ===
#
# Risposta generata dal modello:
#
# RGB: (255, 50, 0) (255, 100, 0) (255, 150, 0) (255, 180, 0) (255, 200, 0)
#
# ==================================================
# RGB matches trovati: 5
# Dettagli matches: [('255', '50', '0'), ('255', '100', '0'), ('255', '150', '0'), ('255', '180', '0'), ('255', '200', '0')]
# Frammento 1: "rgb(255, 50, 0)"
# Frammento 2: "rgb(255, 100, 0)"
# Frammento 3: "rgb(255, 150, 0)"
# Frammento 4: "rgb(255, 180, 0)"
# Frammento 5: "rgb(255, 200, 0)"
# Riga CSV: ['000667.mp3', '"rgb(255, 50, 0)"', '"rgb(255, 100, 0)"', '"rgb(255, 150, 0)"', '"rgb(255, 180, 0)"', '"rgb(255, 200, 0)"']
#
# === Elaborazione canzone 36: 000676.mp3 ===
#
# Risposta generata dal modello:
#
# RGB: (140, 170, 100) (30, 20, 50) (200, 100, 50) (170, 140, 80) (220, 150, 60)
#
# ==================================================
# RGB matches trovati: 5
# Dettagli matches: [('140', '170', '100'), ('30', '20', '50'), ('200', '100', '50'), ('170', '140', '80'), ('220', '150', '60')]
# Frammento 1: "rgb(140, 170, 100)"
# Frammento 2: "rgb(30, 20, 50)"
# Frammento 3: "rgb(200, 100, 50)"
# Frammento 4: "rgb(170, 140, 80)"
# Frammento 5: "rgb(220, 150, 60)"
# Riga CSV: ['000676.mp3', '"rgb(140, 170, 100)"', '"rgb(30, 20, 50)"', '"rgb(200, 100, 50)"', '"rgb(170, 140, 80)"', '"rgb(220, 150, 60)"']
#
# === Elaborazione canzone 37: 000690.mp3 ===
#
# Risposta generata dal modello:
#
# RGB: (230, 50, 30) (100, 30, 50) (200, 50, 30) (230, 50, 30) (230, 50, 30)
#
# ==================================================
# RGB matches trovati: 5
# Dettagli matches: [('230', '50', '30'), ('100', '30', '50'), ('200', '50', '30'), ('230', '50', '30'), ('230', '50', '30')]
# Frammento 1: "rgb(230, 50, 30)"
# Frammento 2: "rgb(100, 30, 50)"
# Frammento 3: "rgb(200, 50, 30)"
# Frammento 4: "rgb(230, 50, 30)"
# Frammento 5: "rgb(230, 50, 30)"
# Riga CSV: ['000690.mp3', '"rgb(230, 50, 30)"', '"rgb(100, 30, 50)"', '"rgb(200, 50, 30)"', '"rgb(230, 50, 30)"', '"rgb(230, 50, 30)"']
#
# === Elaborazione canzone 38: 000694.mp3 ===
#
# Risposta generata dal modello:
#
# RGB: (255, 100, 30) (255, 150, 50) (255, 180, 50) (255, 190, 60) (30, 30, 30)
#
# ==================================================
# RGB matches trovati: 5
# Dettagli matches: [('255', '100', '30'), ('255', '150', '50'), ('255', '180', '50'), ('255', '190', '60'), ('30', '30', '30')]
# Frammento 1: "rgb(255, 100, 30)"
# Frammento 2: "rgb(255, 150, 50)"
# Frammento 3: "rgb(255, 180, 50)"
# Frammento 4: "rgb(255, 190, 60)"
# Frammento 5: "rgb(30, 30, 30)"
# Riga CSV: ['000694.mp3', '"rgb(255, 100, 30)"', '"rgb(255, 150, 50)"', '"rgb(255, 180, 50)"', '"rgb(255, 190, 60)"', '"rgb(30, 30, 30)"']
#
# === Elaborazione canzone 39: 000695.mp3 ===
#
# Risposta generata dal modello:
#
# RGB: (255, 30, 30) (128, 128, 64) (255, 165, 0) (255, 0, 0) (128, 0, 128)
#
# ==================================================
# RGB matches trovati: 5
# Dettagli matches: [('255', '30', '30'), ('128', '128', '64'), ('255', '165', '0'), ('255', '0', '0'), ('128', '0', '128')]
# Frammento 1: "rgb(255, 30, 30)"
# Frammento 2: "rgb(128, 128, 64)"
# Frammento 3: "rgb(255, 165, 0)"
# Frammento 4: "rgb(255, 0, 0)"
# Frammento 5: "rgb(128, 0, 128)"
# Riga CSV: ['000695.mp3', '"rgb(255, 30, 30)"', '"rgb(128, 128, 64)"', '"rgb(255, 165, 0)"', '"rgb(255, 0, 0)"', '"rgb(128, 0, 128)"']
#
# === Elaborazione canzone 40: 000704.mp3 ===
#
# Risposta generata dal modello:
#
# RGB: (170, 200, 100) (200, 180, 120) (210, 150, 80) (220, 160, 60) (230, 140, 40)
#
# ==================================================
# RGB matches trovati: 5
# Dettagli matches: [('170', '200', '100'), ('200', '180', '120'), ('210', '150', '80'), ('220', '160', '60'), ('230', '140', '40')]
# Frammento 1: "rgb(170, 200, 100)"
# Frammento 2: "rgb(200, 180, 120)"
# Frammento 3: "rgb(210, 150, 80)"
# Frammento 4: "rgb(220, 160, 60)"
# Frammento 5: "rgb(230, 140, 40)"
# Riga CSV: ['000704.mp3', '"rgb(170, 200, 100)"', '"rgb(200, 180, 120)"', '"rgb(210, 150, 80)"', '"rgb(220, 160, 60)"', '"rgb(230, 140, 40)"']
#
# === Elaborazione canzone 41: 000705.mp3 ===
#
# Risposta generata dal modello:
#
# RGB: (255, 100, 50) (255, 150, 50) (255, 170, 50) (255, 180, 50) (255, 190, 50)
#
# ==================================================
# RGB matches trovati: 5
# Dettagli matches: [('255', '100', '50'), ('255', '150', '50'), ('255', '170', '50'), ('255', '180', '50'), ('255', '190', '50')]
# Frammento 1: "rgb(255, 100, 50)"
# Frammento 2: "rgb(255, 150, 50)"
# Frammento 3: "rgb(255, 170, 50)"
# Frammento 4: "rgb(255, 180, 50)"
# Frammento 5: "rgb(255, 190, 50)"
# Riga CSV: ['000705.mp3', '"rgb(255, 100, 50)"', '"rgb(255, 150, 50)"', '"rgb(255, 170, 50)"', '"rgb(255, 180, 50)"', '"rgb(255, 190, 50)"']
#
# === Elaborazione canzone 42: 000706.mp3 ===
#
# Risposta generata dal modello:
#
# RGB: (230, 100, 30) (120, 180, 80) (200, 150, 50) (100, 160, 100) (180, 120, 60)
#
# ==================================================
# RGB matches trovati: 5
# Dettagli matches: [('230', '100', '30'), ('120', '180', '80'), ('200', '150', '50'), ('100', '160', '100'), ('180', '120', '60')]
# Frammento 1: "rgb(230, 100, 30)"
# Frammento 2: "rgb(120, 180, 80)"
# Frammento 3: "rgb(200, 150, 50)"
# Frammento 4: "rgb(100, 160, 100)"
# Frammento 5: "rgb(180, 120, 60)"
# Riga CSV: ['000706.mp3', '"rgb(230, 100, 30)"', '"rgb(120, 180, 80)"', '"rgb(200, 150, 50)"', '"rgb(100, 160, 100)"', '"rgb(180, 120, 60)"']
#
# === Elaborazione canzone 43: 000707.mp3 ===
#
# Risposta generata dal modello:
#
# RGB: (220, 50, 30) (120, 80, 60) (200, 100, 40) (230, 60, 30) (150, 70, 40)
#
# ==================================================
# RGB matches trovati: 5
# Dettagli matches: [('220', '50', '30'), ('120', '80', '60'), ('200', '100', '40'), ('230', '60', '30'), ('150', '70', '40')]
# Frammento 1: "rgb(220, 50, 30)"
# Frammento 2: "rgb(120, 80, 60)"
# Frammento 3: "rgb(200, 100, 40)"
# Frammento 4: "rgb(230, 60, 30)"
# Frammento 5: "rgb(150, 70, 40)"
# Riga CSV: ['000707.mp3', '"rgb(220, 50, 30)"', '"rgb(120, 80, 60)"', '"rgb(200, 100, 40)"', '"rgb(230, 60, 30)"', '"rgb(150, 70, 40)"']
#
# === Elaborazione canzone 44: 000708.mp3 ===
#
# Risposta generata dal modello:
#
# RGB: (255, 102, 34) (255, 153, 51) (255, 178, 34) (102, 34, 0) (255, 102, 34)
#
# ==================================================
# RGB matches trovati: 5
# Dettagli matches: [('255', '102', '34'), ('255', '153', '51'), ('255', '178', '34'), ('102', '34', '0'), ('255', '102', '34')]
# Frammento 1: "rgb(255, 102, 34)"
# Frammento 2: "rgb(255, 153, 51)"
# Frammento 3: "rgb(255, 178, 34)"
# Frammento 4: "rgb(102, 34, 0)"
# Frammento 5: "rgb(255, 102, 34)"
# Riga CSV: ['000708.mp3', '"rgb(255, 102, 34)"', '"rgb(255, 153, 51)"', '"rgb(255, 178, 34)"', '"rgb(102, 34, 0)"', '"rgb(255, 102, 34)"']
#
# === Elaborazione canzone 45: 000709.mp3 ===
#
# Risposta generata dal modello:
#
# RGB: (200, 100, 50) (200, 100, 50) (200, 150, 50) (100, 200, 50) (150, 150, 50)
#
# ==================================================
# RGB matches trovati: 5
# Dettagli matches: [('200', '100', '50'), ('200', '100', '50'), ('200', '150', '50'), ('100', '200', '50'), ('150', '150', '50')]
# Frammento 1: "rgb(200, 100, 50)"
# Frammento 2: "rgb(200, 100, 50)"
# Frammento 3: "rgb(200, 150, 50)"
# Frammento 4: "rgb(100, 200, 50)"
# Frammento 5: "rgb(150, 150, 50)"
# Riga CSV: ['000709.mp3', '"rgb(200, 100, 50)"', '"rgb(200, 100, 50)"', '"rgb(200, 150, 50)"', '"rgb(100, 200, 50)"', '"rgb(150, 150, 50)"']
#
# === Elaborazione canzone 46: 000714.mp3 ===
#
# Risposta generata dal modello:
#
# RGB: (10, 30, 15) (120, 60, 20) (15, 10, 30) (120, 30, 10) (10, 150, 10)
#
# ==================================================
# RGB matches trovati: 5
# Dettagli matches: [('10', '30', '15'), ('120', '60', '20'), ('15', '10', '30'), ('120', '30', '10'), ('10', '150', '10')]
# Frammento 1: "rgb(10, 30, 15)"
# Frammento 2: "rgb(120, 60, 20)"
# Frammento 3: "rgb(15, 10, 30)"
# Frammento 4: "rgb(120, 30, 10)"
# Frammento 5: "rgb(10, 150, 10)"
# Riga CSV: ['000714.mp3', '"rgb(10, 30, 15)"', '"rgb(120, 60, 20)"', '"rgb(15, 10, 30)"', '"rgb(120, 30, 10)"', '"rgb(10, 150, 10)"']
#
# === Elaborazione canzone 47: 000715.mp3 ===
#
# Risposta generata dal modello:
#
# RGB: (120, 180, 50) (60, 40, 10) (150, 160, 120) (130, 170, 60) (140, 165, 55)
#
# ==================================================
# RGB matches trovati: 5
# Dettagli matches: [('120', '180', '50'), ('60', '40', '10'), ('150', '160', '120'), ('130', '170', '60'), ('140', '165', '55')]
# Frammento 1: "rgb(120, 180, 50)"
# Frammento 2: "rgb(60, 40, 10)"
# Frammento 3: "rgb(150, 160, 120)"
# Frammento 4: "rgb(130, 170, 60)"
# Frammento 5: "rgb(140, 165, 55)"
# Riga CSV: ['000715.mp3', '"rgb(120, 180, 50)"', '"rgb(60, 40, 10)"', '"rgb(150, 160, 120)"', '"rgb(130, 170, 60)"', '"rgb(140, 165, 55)"']
#
# === Elaborazione canzone 48: 000716.mp3 ===
#
# Risposta generata dal modello:
#
# RGB: (120, 180, 45) (100, 160, 30) (40, 20, 10) (150, 190, 60) (180, 150, 30)
#
# ==================================================
# RGB matches trovati: 5
# Dettagli matches: [('120', '180', '45'), ('100', '160', '30'), ('40', '20', '10'), ('150', '190', '60'), ('180', '150', '30')]
# Frammento 1: "rgb(120, 180, 45)"
# Frammento 2: "rgb(100, 160, 30)"
# Frammento 3: "rgb(40, 20, 10)"
# Frammento 4: "rgb(150, 190, 60)"
# Frammento 5: "rgb(180, 150, 30)"
# Riga CSV: ['000716.mp3', '"rgb(120, 180, 45)"', '"rgb(100, 160, 30)"', '"rgb(40, 20, 10)"', '"rgb(150, 190, 60)"', '"rgb(180, 150, 30)"']
#
# === Elaborazione canzone 49: 000718.mp3 ===
#
# Risposta generata dal modello:
#
# RGB: (120, 170, 80) (150, 100, 50) (140, 180, 100) (130, 160, 60) (160, 110, 40)
#
# ==================================================
# RGB matches trovati: 5
# Dettagli matches: [('120', '170', '80'), ('150', '100', '50'), ('140', '180', '100'), ('130', '160', '60'), ('160', '110', '40')]
# Frammento 1: "rgb(120, 170, 80)"
# Frammento 2: "rgb(150, 100, 50)"
# Frammento 3: "rgb(140, 180, 100)"
# Frammento 4: "rgb(130, 160, 60)"
# Frammento 5: "rgb(160, 110, 40)"
# Riga CSV: ['000718.mp3', '"rgb(120, 170, 80)"', '"rgb(150, 100, 50)"', '"rgb(140, 180, 100)"', '"rgb(130, 160, 60)"', '"rgb(160, 110, 40)"']
#
# === Elaborazione canzone 50: 000777.mp3 ===
#
# Risposta generata dal modello:
#
# RGB: (140, 190, 120) (200, 50, 50) (160, 180, 100) (220, 180, 100) (130, 180, 120)
#
# ==================================================
# RGB matches trovati: 5
# Dettagli matches: [('140', '190', '120'), ('200', '50', '50'), ('160', '180', '100'), ('220', '180', '100'), ('130', '180', '120')]
# Frammento 1: "rgb(140, 190, 120)"
# Frammento 2: "rgb(200, 50, 50)"
# Frammento 3: "rgb(160, 180, 100)"
# Frammento 4: "rgb(220, 180, 100)"
# Frammento 5: "rgb(130, 180, 120)"
# Riga CSV: ['000777.mp3', '"rgb(140, 190, 120)"', '"rgb(200, 50, 50)"', '"rgb(160, 180, 100)"', '"rgb(220, 180, 100)"', '"rgb(130, 180, 120)"']
#
# === Elaborazione canzone 51: 000814.mp3 ===
#
# Risposta generata dal modello:
#
# RGB: (10, 180, 180) (120, 150, 100) (150, 120, 50) (10, 180, 180) (200, 160, 60)
#
# ==================================================
# RGB matches trovati: 5
# Dettagli matches: [('10', '180', '180'), ('120', '150', '100'), ('150', '120', '50'), ('10', '180', '180'), ('200', '160', '60')]
# Frammento 1: "rgb(10, 180, 180)"
# Frammento 2: "rgb(120, 150, 100)"
# Frammento 3: "rgb(150, 120, 50)"
# Frammento 4: "rgb(10, 180, 180)"
# Frammento 5: "rgb(200, 160, 60)"
# Riga CSV: ['000814.mp3', '"rgb(10, 180, 180)"', '"rgb(120, 150, 100)"', '"rgb(150, 120, 50)"', '"rgb(10, 180, 180)"', '"rgb(200, 160, 60)"']
#
# === Elaborazione canzone 52: 000821.mp3 ===
#
# Risposta generata dal modello:
#
# RGB: (120, 160, 80) (180, 120, 60) (150, 170, 85) (130, 165, 70) (140, 155, 65)
#
# ==================================================
# RGB matches trovati: 5
# Dettagli matches: [('120', '160', '80'), ('180', '120', '60'), ('150', '170', '85'), ('130', '165', '70'), ('140', '155', '65')]
# Frammento 1: "rgb(120, 160, 80)"
# Frammento 2: "rgb(180, 120, 60)"
# Frammento 3: "rgb(150, 170, 85)"
# Frammento 4: "rgb(130, 165, 70)"
# Frammento 5: "rgb(140, 155, 65)"
# Riga CSV: ['000821.mp3', '"rgb(120, 160, 80)"', '"rgb(180, 120, 60)"', '"rgb(150, 170, 85)"', '"rgb(130, 165, 70)"', '"rgb(140, 155, 65)"']
#
# === Elaborazione canzone 53: 000822.mp3 ===
#
# Risposta generata dal modello:
#
# RGB: (255, 100, 30) (100, 255, 50) (50, 50, 255) (255, 255, 100) (150, 150, 150)
#
# ==================================================
# RGB matches trovati: 5
# Dettagli matches: [('255', '100', '30'), ('100', '255', '50'), ('50', '50', '255'), ('255', '255', '100'), ('150', '150', '150')]
# Frammento 1: "rgb(255, 100, 30)"
# Frammento 2: "rgb(100, 255, 50)"
# Frammento 3: "rgb(50, 50, 255)"
# Frammento 4: "rgb(255, 255, 100)"
# Frammento 5: "rgb(150, 150, 150)"
# Riga CSV: ['000822.mp3', '"rgb(255, 100, 30)"', '"rgb(100, 255, 50)"', '"rgb(50, 50, 255)"', '"rgb(255, 255, 100)"', '"rgb(150, 150, 150)"']
#
# === Elaborazione canzone 54: 000825.mp3 ===
#
# Risposta generata dal modello:
#
# RGB: (255, 10, 10) (255, 10, 10) (255, 10, 10) (255, 10, 10) (255, 10, 10)
#
# ==================================================
# RGB matches trovati: 5
# Dettagli matches: [('255', '10', '10'), ('255', '10', '10'), ('255', '10', '10'), ('255', '10', '10'), ('255', '10', '10')]
# Frammento 1: "rgb(255, 10, 10)"
# Frammento 2: "rgb(255, 10, 10)"
# Frammento 3: "rgb(255, 10, 10)"
# Frammento 4: "rgb(255, 10, 10)"
# Frammento 5: "rgb(255, 10, 10)"
# Riga CSV: ['000825.mp3', '"rgb(255, 10, 10)"', '"rgb(255, 10, 10)"', '"rgb(255, 10, 10)"', '"rgb(255, 10, 10)"', '"rgb(255, 10, 10)"']
#
# === Elaborazione canzone 55: 000853.mp3 ===
#
# Risposta generata dal modello:
#
# RGB: (200, 60, 40) (210, 70, 30) (220, 80, 20) (180, 50, 30) (150, 40, 20)
#
# ==================================================
# RGB matches trovati: 5
# Dettagli matches: [('200', '60', '40'), ('210', '70', '30'), ('220', '80', '20'), ('180', '50', '30'), ('150', '40', '20')]
# Frammento 1: "rgb(200, 60, 40)"
# Frammento 2: "rgb(210, 70, 30)"
# Frammento 3: "rgb(220, 80, 20)"
# Frammento 4: "rgb(180, 50, 30)"
# Frammento 5: "rgb(150, 40, 20)"
# Riga CSV: ['000853.mp3', '"rgb(200, 60, 40)"', '"rgb(210, 70, 30)"', '"rgb(220, 80, 20)"', '"rgb(180, 50, 30)"', '"rgb(150, 40, 20)"']
#
# === Elaborazione canzone 56: 000890.mp3 ===
#
# Risposta generata dal modello:
#
# RGB: (120, 30, 50) (150, 120, 80) (180, 150, 100) (100, 180, 120) (140, 140, 100)
#
# ==================================================
# RGB matches trovati: 5
# Dettagli matches: [('120', '30', '50'), ('150', '120', '80'), ('180', '150', '100'), ('100', '180', '120'), ('140', '140', '100')]
# Frammento 1: "rgb(120, 30, 50)"
# Frammento 2: "rgb(150, 120, 80)"
# Frammento 3: "rgb(180, 150, 100)"
# Frammento 4: "rgb(100, 180, 120)"
# Frammento 5: "rgb(140, 140, 100)"
# Riga CSV: ['000890.mp3', '"rgb(120, 30, 50)"', '"rgb(150, 120, 80)"', '"rgb(180, 150, 100)"', '"rgb(100, 180, 120)"', '"rgb(140, 140, 100)"']
#
# === Elaborazione canzone 57: 000892.mp3 ===
#
# Risposta generata dal modello:
#
# RGB: (140, 100, 50) (200, 150, 80) (180, 120, 60) (210, 160, 70) (160, 110, 40)
#
# ==================================================
# RGB matches trovati: 5
# Dettagli matches: [('140', '100', '50'), ('200', '150', '80'), ('180', '120', '60'), ('210', '160', '70'), ('160', '110', '40')]
# Frammento 1: "rgb(140, 100, 50)"
# Frammento 2: "rgb(200, 150, 80)"
# Frammento 3: "rgb(180, 120, 60)"
# Frammento 4: "rgb(210, 160, 70)"
# Frammento 5: "rgb(160, 110, 40)"
# Riga CSV: ['000892.mp3', '"rgb(140, 100, 50)"', '"rgb(200, 150, 80)"', '"rgb(180, 120, 60)"', '"rgb(210, 160, 70)"', '"rgb(160, 110, 40)"']
#
# === Elaborazione canzone 58: 000897.mp3 ===
#
# Risposta generata dal modello:
#
# RGB: (255, 50, 0) (255, 50, 0) (255, 50, 0) (255, 50, 0) (50, 50, 255)
#
# ==================================================
# RGB matches trovati: 5
# Dettagli matches: [('255', '50', '0'), ('255', '50', '0'), ('255', '50', '0'), ('255', '50', '0'), ('50', '50', '255')]
# Frammento 1: "rgb(255, 50, 0)"
# Frammento 2: "rgb(255, 50, 0)"
# Frammento 3: "rgb(255, 50, 0)"
# Frammento 4: "rgb(255, 50, 0)"
# Frammento 5: "rgb(50, 50, 255)"
# Riga CSV: ['000897.mp3', '"rgb(255, 50, 0)"', '"rgb(255, 50, 0)"', '"rgb(255, 50, 0)"', '"rgb(255, 50, 0)"', '"rgb(50, 50, 255)"']
#
# === Elaborazione canzone 59: 000993.mp3 ===
#
# Risposta generata dal modello:
#
# RGB: (200, 100, 50) (30, 30, 60) (150, 50, 150) (180, 80, 30) (220, 150, 50)
#
# ==================================================
# RGB matches trovati: 5
# Dettagli matches: [('200', '100', '50'), ('30', '30', '60'), ('150', '50', '150'), ('180', '80', '30'), ('220', '150', '50')]
# Frammento 1: "rgb(200, 100, 50)"
# Frammento 2: "rgb(30, 30, 60)"
# Frammento 3: "rgb(150, 50, 150)"
# Frammento 4: "rgb(180, 80, 30)"
# Frammento 5: "rgb(220, 150, 50)"
# Riga CSV: ['000993.mp3', '"rgb(200, 100, 50)"', '"rgb(30, 30, 60)"', '"rgb(150, 50, 150)"', '"rgb(180, 80, 30)"', '"rgb(220, 150, 50)"']
#
# === Elaborazione canzone 60: 000995.mp3 ===
#
# Risposta generata dal modello:
#
# RGB: (220, 30, 30) (230, 40, 35) (210, 20, 25) (100, 50, 50) (150, 30, 30)
#
# ==================================================
# RGB matches trovati: 5
# Dettagli matches: [('220', '30', '30'), ('230', '40', '35'), ('210', '20', '25'), ('100', '50', '50'), ('150', '30', '30')]
# Frammento 1: "rgb(220, 30, 30)"
# Frammento 2: "rgb(230, 40, 35)"
# Frammento 3: "rgb(210, 20, 25)"
# Frammento 4: "rgb(100, 50, 50)"
# Frammento 5: "rgb(150, 30, 30)"
# Riga CSV: ['000995.mp3', '"rgb(220, 30, 30)"', '"rgb(230, 40, 35)"', '"rgb(210, 20, 25)"', '"rgb(100, 50, 50)"', '"rgb(150, 30, 30)"']
#
# === Elaborazione canzone 61: 000997.mp3 ===
#
# Risposta generata dal modello:
#
# RGB: (255, 30, 30) (255, 60, 30) (255, 90, 30) (255, 120, 30) (255, 150, 30)
#
# ==================================================
# RGB matches trovati: 5
# Dettagli matches: [('255', '30', '30'), ('255', '60', '30'), ('255', '90', '30'), ('255', '120', '30'), ('255', '150', '30')]
# Frammento 1: "rgb(255, 30, 30)"
# Frammento 2: "rgb(255, 60, 30)"
# Frammento 3: "rgb(255, 90, 30)"
# Frammento 4: "rgb(255, 120, 30)"
# Frammento 5: "rgb(255, 150, 30)"
# Riga CSV: ['000997.mp3', '"rgb(255, 30, 30)"', '"rgb(255, 60, 30)"', '"rgb(255, 90, 30)"', '"rgb(255, 120, 30)"', '"rgb(255, 150, 30)"']
#
# === Elaborazione canzone 62: 000998.mp3 ===
#
# Risposta generata dal modello:
#
# RGB: (200, 50, 30) (220, 60, 35) (30, 50, 100) (180, 30, 120) (150, 40, 110)
#
# ==================================================
# RGB matches trovati: 5
# Dettagli matches: [('200', '50', '30'), ('220', '60', '35'), ('30', '50', '100'), ('180', '30', '120'), ('150', '40', '110')]
# Frammento 1: "rgb(200, 50, 30)"
# Frammento 2: "rgb(220, 60, 35)"
# Frammento 3: "rgb(30, 50, 100)"
# Frammento 4: "rgb(180, 30, 120)"
# Frammento 5: "rgb(150, 40, 110)"
# Riga CSV: ['000998.mp3', '"rgb(200, 50, 30)"', '"rgb(220, 60, 35)"', '"rgb(30, 50, 100)"', '"rgb(180, 30, 120)"', '"rgb(150, 40, 110)"']
#
# === Elaborazione canzone 63: 005006.mp3 ===
#
# Risposta generata dal modello:
#
# RGB: (255, 50, 30) (255, 50, 30) (255, 50, 30) (255, 50, 30) (255, 50, 30)
#
# ==================================================
# RGB matches trovati: 5
# Dettagli matches: [('255', '50', '30'), ('255', '50', '30'), ('255', '50', '30'), ('255', '50', '30'), ('255', '50', '30')]
# Frammento 1: "rgb(255, 50, 30)"
# Frammento 2: "rgb(255, 50, 30)"
# Frammento 3: "rgb(255, 50, 30)"
# Frammento 4: "rgb(255, 50, 30)"
# Frammento 5: "rgb(255, 50, 30)"
# Riga CSV: ['005006.mp3', '"rgb(255, 50, 30)"', '"rgb(255, 50, 30)"', '"rgb(255, 50, 30)"', '"rgb(255, 50, 30)"', '"rgb(255, 50, 30)"']
#
# === Elaborazione canzone 64: 005156.mp3 ===
#
# Risposta generata dal modello:
#
# RGB: (120, 180, 100) (150, 190, 110) (130, 170, 90) (140, 185, 105) (135, 180, 95)
#
# ==================================================
# RGB matches trovati: 5
# Dettagli matches: [('120', '180', '100'), ('150', '190', '110'), ('130', '170', '90'), ('140', '185', '105'), ('135', '180', '95')]
# Frammento 1: "rgb(120, 180, 100)"
# Frammento 2: "rgb(150, 190, 110)"
# Frammento 3: "rgb(130, 170, 90)"
# Frammento 4: "rgb(140, 185, 105)"
# Frammento 5: "rgb(135, 180, 95)"
# Riga CSV: ['005156.mp3', '"rgb(120, 180, 100)"', '"rgb(150, 190, 110)"', '"rgb(130, 170, 90)"', '"rgb(140, 185, 105)"', '"rgb(135, 180, 95)"']
#
# === Elaborazione canzone 65: 005157.mp3 ===
#
# Risposta generata dal modello:
#
# RGB: (170, 200, 120) (180, 210, 130) (160, 200, 110) (175, 215, 125) (165, 205, 115)
#
# ==================================================
# RGB matches trovati: 5
# Dettagli matches: [('170', '200', '120'), ('180', '210', '130'), ('160', '200', '110'), ('175', '215', '125'), ('165', '205', '115')]
# Frammento 1: "rgb(170, 200, 120)"
# Frammento 2: "rgb(180, 210, 130)"
# Frammento 3: "rgb(160, 200, 110)"
# Frammento 4: "rgb(175, 215, 125)"
# Frammento 5: "rgb(165, 205, 115)"
# Riga CSV: ['005157.mp3', '"rgb(170, 200, 120)"', '"rgb(180, 210, 130)"', '"rgb(160, 200, 110)"', '"rgb(175, 215, 125)"', '"rgb(165, 205, 115)"']
#
# === Elaborazione canzone 66: 005158.mp3 ===
#
# Risposta generata dal modello:
#
# RGB: (200, 50, 30) (100, 150, 50) (150, 180, 120) (120, 80, 100) (180, 140, 100)
#
# ==================================================
# RGB matches trovati: 5
# Dettagli matches: [('200', '50', '30'), ('100', '150', '50'), ('150', '180', '120'), ('120', '80', '100'), ('180', '140', '100')]
# Frammento 1: "rgb(200, 50, 30)"
# Frammento 2: "rgb(100, 150, 50)"
# Frammento 3: "rgb(150, 180, 120)"
# Frammento 4: "rgb(120, 80, 100)"
# Frammento 5: "rgb(180, 140, 100)"
# Riga CSV: ['005158.mp3', '"rgb(200, 50, 30)"', '"rgb(100, 150, 50)"', '"rgb(150, 180, 120)"', '"rgb(120, 80, 100)"', '"rgb(180, 140, 100)"']
#
# === Elaborazione canzone 67: 005159.mp3 ===
#
# Risposta generata dal modello:
#
# RGB: (120, 160, 120) (130, 150, 110) (125, 155, 115) (128, 158, 118) (122, 152, 112)
#
# ==================================================
# RGB matches trovati: 5
# Dettagli matches: [('120', '160', '120'), ('130', '150', '110'), ('125', '155', '115'), ('128', '158', '118'), ('122', '152', '112')]
# Frammento 1: "rgb(120, 160, 120)"
# Frammento 2: "rgb(130, 150, 110)"
# Frammento 3: "rgb(125, 155, 115)"
# Frammento 4: "rgb(128, 158, 118)"
# Frammento 5: "rgb(122, 152, 112)"
# Riga CSV: ['005159.mp3', '"rgb(120, 160, 120)"', '"rgb(130, 150, 110)"', '"rgb(125, 155, 115)"', '"rgb(128, 158, 118)"', '"rgb(122, 152, 112)"']
#
# === Elaborazione canzone 68: 005169.mp3 ===
#
# Risposta generata dal modello:
#
# RGB: (100, 150, 100) (120, 160, 90) (110, 145, 95) (125, 165, 85) (105, 155, 90)
#
# ==================================================
# RGB matches trovati: 5
# Dettagli matches: [('100', '150', '100'), ('120', '160', '90'), ('110', '145', '95'), ('125', '165', '85'), ('105', '155', '90')]
# Frammento 1: "rgb(100, 150, 100)"
# Frammento 2: "rgb(120, 160, 90)"
# Frammento 3: "rgb(110, 145, 95)"
# Frammento 4: "rgb(125, 165, 85)"
# Frammento 5: "rgb(105, 155, 90)"
# Riga CSV: ['005169.mp3', '"rgb(100, 150, 100)"', '"rgb(120, 160, 90)"', '"rgb(110, 145, 95)"', '"rgb(125, 165, 85)"', '"rgb(105, 155, 90)"']
#
# === Elaborazione canzone 69: 005170.mp3 ===
#
# Risposta generata dal modello:
#
# RGB: (170, 213, 170) (200, 210, 180) (190, 200, 170) (180, 205, 165) (175, 205, 160)
#
# ==================================================
# RGB matches trovati: 5
# ...
# RGB matches trovati: 5
# Dettagli matches: [('100', '150', '50'), ('80', '120', '60'), ('130', '160', '70'), ('110', '140', '55'), ('90', '130', '65')]
# Frammento 1: "rgb(100, 150, 50)"
# Frammento 2: "rgb(80, 120, 60)"
# Frammento 3: "rgb(130, 160, 70)"
# Frammento 4: "rgb(110, 140, 55)"
# Frammento 5: "rgb(90, 130, 65)"
# Riga CSV: ['005940.mp3', '"rgb(100, 150, 50)"', '"rgb(80, 120, 60)"', '"rgb(130, 160, 70)"', '"rgb(110, 140, 55)"', '"rgb(90, 130, 65)"']
#
# === Elaborazione canzone 80: 025028.mp3 ===
#
# Risposta generata dal modello:
#
# RGB: (100, 20, 20) (180, 120, 60) (100, 150, 150) (200, 100, 50) (180, 180, 60)
#
# ==================================================
# RGB matches trovati: 5
# Dettagli matches: [('100', '20', '20'), ('180', '120', '60'), ('100', '150', '150'), ('200', '100', '50'), ('180', '180', '60')]
# Frammento 1: "rgb(100, 20, 20)"
# Frammento 2: "rgb(180, 120, 60)"
# Frammento 3: "rgb(100, 150, 150)"
# Frammento 4: "rgb(200, 100, 50)"
# Frammento 5: "rgb(180, 180, 60)"
# Riga CSV: ['025028.mp3', '"rgb(100, 20, 20)"', '"rgb(180, 120, 60)"', '"rgb(100, 150, 150)"', '"rgb(200, 100, 50)"', '"rgb(180, 180, 60)"']
#
# === Elaborazione canzone 81: 025029.mp3 ===
#
# Risposta generata dal modello:
#
# RGB: (50, 70, 100) (120, 160, 100) (100, 140, 80) (130, 150, 110) (180, 120, 60)
#
# ==================================================
# RGB matches trovati: 5
# Dettagli matches: [('50', '70', '100'), ('120', '160', '100'), ('100', '140', '80'), ('130', '150', '110'), ('180', '120', '60')]
# Frammento 1: "rgb(50, 70, 100)"
# Frammento 2: "rgb(120, 160, 100)"
# Frammento 3: "rgb(100, 140, 80)"
# Frammento 4: "rgb(130, 150, 110)"
# Frammento 5: "rgb(180, 120, 60)"
# Riga CSV: ['025029.mp3', '"rgb(50, 70, 100)"', '"rgb(120, 160, 100)"', '"rgb(100, 140, 80)"', '"rgb(130, 150, 110)"', '"rgb(180, 120, 60)"']
#
# === Elaborazione canzone 82: 025030.mp3 ===
#
# Risposta generata dal modello:
#
# RGB: (10, 10, 10) (150, 100, 50) (170, 10, 10) (10, 170, 10) (10, 10, 170)
#
# ==================================================
# RGB matches trovati: 5
# Dettagli matches: [('10', '10', '10'), ('150', '100', '50'), ('170', '10', '10'), ('10', '170', '10'), ('10', '10', '170')]
# Frammento 1: "rgb(10, 10, 10)"
# Frammento 2: "rgb(150, 100, 50)"
# Frammento 3: "rgb(170, 10, 10)"
# Frammento 4: "rgb(10, 170, 10)"
# Frammento 5: "rgb(10, 10, 170)"
# Riga CSV: ['025030.mp3', '"rgb(10, 10, 10)"', '"rgb(150, 100, 50)"', '"rgb(170, 10, 10)"', '"rgb(10, 170, 10)"', '"rgb(10, 10, 170)"']
#
# === Elaborazione canzone 83: 025031.mp3 ===
#
# Risposta generata dal modello:
#
# RGB: (10, 10, 150) (10, 10, 150) (160, 160, 160) (10, 10, 150) (10, 10, 150)
#
# ==================================================
# RGB matches trovati: 5
# Dettagli matches: [('10', '10', '150'), ('10', '10', '150'), ('160', '160', '160'), ('10', '10', '150'), ('10', '10', '150')]
# Frammento 1: "rgb(10, 10, 150)"
# Frammento 2: "rgb(10, 10, 150)"
# Frammento 3: "rgb(160, 160, 160)"
# Frammento 4: "rgb(10, 10, 150)"
# Frammento 5: "rgb(10, 10, 150)"
# Riga CSV: ['025031.mp3', '"rgb(10, 10, 150)"', '"rgb(10, 10, 150)"', '"rgb(160, 160, 160)"', '"rgb(10, 10, 150)"', '"rgb(10, 10, 150)"']
#
# === Elaborazione canzone 84: 025032.mp3 ===
#
# Risposta generata dal modello:
#
# RGB: (230, 50, 30) (100, 150, 50) (200, 100, 50) (150, 150, 100) (220, 120, 60)
#
# ==================================================
# RGB matches trovati: 5
# Dettagli matches: [('230', '50', '30'), ('100', '150', '50'), ('200', '100', '50'), ('150', '150', '100'), ('220', '120', '60')]
# Frammento 1: "rgb(230, 50, 30)"
# Frammento 2: "rgb(100, 150, 50)"
# Frammento 3: "rgb(200, 100, 50)"
# Frammento 4: "rgb(150, 150, 100)"
# Frammento 5: "rgb(220, 120, 60)"
# Riga CSV: ['025032.mp3', '"rgb(230, 50, 30)"', '"rgb(100, 150, 50)"', '"rgb(200, 100, 50)"', '"rgb(150, 150, 100)"', '"rgb(220, 120, 60)"']
#
# === Elaborazione canzone 85: 025033.mp3 ===
#
# Risposta generata dal modello:
#
# RGB: (255, 100, 50) (255, 150, 50) (255, 170, 50) (255, 190, 50) (255, 210, 50)
#
# ==================================================
# RGB matches trovati: 5
# Dettagli matches: [('255', '100', '50'), ('255', '150', '50'), ('255', '170', '50'), ('255', '190', '50'), ('255', '210', '50')]
# Frammento 1: "rgb(255, 100, 50)"
# Frammento 2: "rgb(255, 150, 50)"
# Frammento 3: "rgb(255, 170, 50)"
# Frammento 4: "rgb(255, 190, 50)"
# Frammento 5: "rgb(255, 210, 50)"
# Riga CSV: ['025033.mp3', '"rgb(255, 100, 50)"', '"rgb(255, 150, 50)"', '"rgb(255, 170, 50)"', '"rgb(255, 190, 50)"', '"rgb(255, 210, 50)"']
#
# === Elaborazione canzone 86: 025055.mp3 ===
#
# Risposta generata dal modello:
#
# RGB: (10, 10, 200) (10, 10, 200) (10, 10, 200) (50, 150, 150) (10, 10, 200)
#
# ==================================================
# RGB matches trovati: 5
# Dettagli matches: [('10', '10', '200'), ('10', '10', '200'), ('10', '10', '200'), ('50', '150', '150'), ('10', '10', '200')]
# Frammento 1: "rgb(10, 10, 200)"
# Frammento 2: "rgb(10, 10, 200)"
# Frammento 3: "rgb(10, 10, 200)"
# Frammento 4: "rgb(50, 150, 150)"
# Frammento 5: "rgb(10, 10, 200)"
# Riga CSV: ['025055.mp3', '"rgb(10, 10, 200)"', '"rgb(10, 10, 200)"', '"rgb(10, 10, 200)"', '"rgb(50, 150, 150)"', '"rgb(10, 10, 200)"']
#
# === Elaborazione canzone 87: 025063.mp3 ===
#
# Risposta generata dal modello:
#
# RGB: (230, 10, 20) (120, 50, 100) (180, 30, 60) (200, 150, 30) (80, 80, 120)
#
# ==================================================
# RGB matches trovati: 5
# Dettagli matches: [('230', '10', '20'), ('120', '50', '100'), ('180', '30', '60'), ('200', '150', '30'), ('80', '80', '120')]
# Frammento 1: "rgb(230, 10, 20)"
# Frammento 2: "rgb(120, 50, 100)"
# Frammento 3: "rgb(180, 30, 60)"
# Frammento 4: "rgb(200, 150, 30)"
# Frammento 5: "rgb(80, 80, 120)"
# Riga CSV: ['025063.mp3', '"rgb(230, 10, 20)"', '"rgb(120, 50, 100)"', '"rgb(180, 30, 60)"', '"rgb(200, 150, 30)"', '"rgb(80, 80, 120)"']
#
# === Elaborazione canzone 88: 025066.mp3 ===
#
# Risposta generata dal modello:
#
# RGB: (100, 150, 50) (140, 130, 60) (120, 110, 40) (130, 120, 50) (110, 140, 60)
#
# ==================================================
# RGB matches trovati: 5
# Dettagli matches: [('100', '150', '50'), ('140', '130', '60'), ('120', '110', '40'), ('130', '120', '50'), ('110', '140', '60')]
# Frammento 1: "rgb(100, 150, 50)"
# Frammento 2: "rgb(140, 130, 60)"
# Frammento 3: "rgb(120, 110, 40)"
# Frammento 4: "rgb(130, 120, 50)"
# Frammento 5: "rgb(110, 140, 60)"
# Riga CSV: ['025066.mp3', '"rgb(100, 150, 50)"', '"rgb(140, 130, 60)"', '"rgb(120, 110, 40)"', '"rgb(130, 120, 50)"', '"rgb(110, 140, 60)"']
#
# === Elaborazione canzone 89: 025104.mp3 ===
#
# Risposta generata dal modello:
#
# RGB: (255, 100, 30) (255, 150, 50) (255, 130, 40) (50, 50, 255) (200, 100, 100)
#
# ==================================================
# RGB matches trovati: 5
# Dettagli matches: [('255', '100', '30'), ('255', '150', '50'), ('255', '130', '40'), ('50', '50', '255'), ('200', '100', '100')]
# Frammento 1: "rgb(255, 100, 30)"
# Frammento 2: "rgb(255, 150, 50)"
# Frammento 3: "rgb(255, 130, 40)"
# Frammento 4: "rgb(50, 50, 255)"
# Frammento 5: "rgb(200, 100, 100)"
# Riga CSV: ['025104.mp3', '"rgb(255, 100, 30)"', '"rgb(255, 150, 50)"', '"rgb(255, 130, 40)"', '"rgb(50, 50, 255)"', '"rgb(200, 100, 100)"']
#
# === Elaborazione canzone 90: 025124.mp3 ===
#
# Risposta generata dal modello:
#
# RGB: (180, 100, 40) (50, 100, 150) (100, 100, 150) (70, 100, 130) (180, 150, 60)
#
# ==================================================
# RGB matches trovati: 5
# Dettagli matches: [('180', '100', '40'), ('50', '100', '150'), ('100', '100', '150'), ('70', '100', '130'), ('180', '150', '60')]
# Frammento 1: "rgb(180, 100, 40)"
# Frammento 2: "rgb(50, 100, 150)"
# Frammento 3: "rgb(100, 100, 150)"
# Frammento 4: "rgb(70, 100, 130)"
# Frammento 5: "rgb(180, 150, 60)"
# Riga CSV: ['025124.mp3', '"rgb(180, 100, 40)"', '"rgb(50, 100, 150)"', '"rgb(100, 100, 150)"', '"rgb(70, 100, 130)"', '"rgb(180, 150, 60)"']
#
# === Elaborazione canzone 91: 025215.mp3 ===
#
# Risposta generata dal modello:
#
# RGB: (120, 180, 50) (140, 150, 60) (160, 130, 40) (200, 180, 50) (220, 170, 40)
#
# ==================================================
# RGB matches trovati: 5
# Dettagli matches: [('120', '180', '50'), ('140', '150', '60'), ('160', '130', '40'), ('200', '180', '50'), ('220', '170', '40')]
# Frammento 1: "rgb(120, 180, 50)"
# Frammento 2: "rgb(140, 150, 60)"
# Frammento 3: "rgb(160, 130, 40)"
# Frammento 4: "rgb(200, 180, 50)"
# Frammento 5: "rgb(220, 170, 40)"
# Riga CSV: ['025215.mp3', '"rgb(120, 180, 50)"', '"rgb(140, 150, 60)"', '"rgb(160, 130, 40)"', '"rgb(200, 180, 50)"', '"rgb(220, 170, 40)"']
#
# === Elaborazione canzone 92: 025216.mp3 ===
#
# Risposta generata dal modello:
#
# RGB: (255, 100, 50) (150, 120, 50) (230, 160, 60) (80, 180, 100) (100, 150, 50)
#
# ==================================================
# RGB matches trovati: 5
# Dettagli matches: [('255', '100', '50'), ('150', '120', '50'), ('230', '160', '60'), ('80', '180', '100'), ('100', '150', '50')]
# Frammento 1: "rgb(255, 100, 50)"
# Frammento 2: "rgb(150, 120, 50)"
# Frammento 3: "rgb(230, 160, 60)"
# Frammento 4: "rgb(80, 180, 100)"
# Frammento 5: "rgb(100, 150, 50)"
# Riga CSV: ['025216.mp3', '"rgb(255, 100, 50)"', '"rgb(150, 120, 50)"', '"rgb(230, 160, 60)"', '"rgb(80, 180, 100)"', '"rgb(100, 150, 50)"']
#
# === Elaborazione canzone 93: 025227.mp3 ===
#
# Risposta generata dal modello:
#
# RGB: (10, 20, 200) (170, 200, 50) (170, 200, 50) (170, 200, 50) (200, 100, 50)
#
# ==================================================
# RGB matches trovati: 5
# Dettagli matches: [('10', '20', '200'), ('170', '200', '50'), ('170', '200', '50'), ('170', '200', '50'), ('200', '100', '50')]
# Frammento 1: "rgb(10, 20, 200)"
# Frammento 2: "rgb(170, 200, 50)"
# Frammento 3: "rgb(170, 200, 50)"
# Frammento 4: "rgb(170, 200, 50)"
# Frammento 5: "rgb(200, 100, 50)"
# Riga CSV: ['025227.mp3', '"rgb(10, 20, 200)"', '"rgb(170, 200, 50)"', '"rgb(170, 200, 50)"', '"rgb(170, 200, 50)"', '"rgb(200, 100, 50)"']
#
# === Elaborazione canzone 94: 025232.mp3 ===
#
# Risposta generata dal modello:
#
# RGB: (10, 10, 10) (150, 180, 120) (30, 30, 50) (120, 150, 80) (200, 200, 150)
#
# ==================================================
# RGB matches trovati: 5
# Dettagli matches: [('10', '10', '10'), ('150', '180', '120'), ('30', '30', '50'), ('120', '150', '80'), ('200', '200', '150')]
# Frammento 1: "rgb(10, 10, 10)"
# Frammento 2: "rgb(150, 180, 120)"
# Frammento 3: "rgb(30, 30, 50)"
# Frammento 4: "rgb(120, 150, 80)"
# Frammento 5: "rgb(200, 200, 150)"
# Riga CSV: ['025232.mp3', '"rgb(10, 10, 10)"', '"rgb(150, 180, 120)"', '"rgb(30, 30, 50)"', '"rgb(120, 150, 80)"', '"rgb(200, 200, 150)"']
#
# === Elaborazione canzone 95: 025233.mp3 ===
#
# Risposta generata dal modello:
#
# RGB: (150, 180, 100) (160, 170, 80) (140, 160, 90) (50, 120, 150) (200, 190, 110)
#
# ==================================================
# RGB matches trovati: 5
# Dettagli matches: [('150', '180', '100'), ('160', '170', '80'), ('140', '160', '90'), ('50', '120', '150'), ('200', '190', '110')]
# Frammento 1: "rgb(150, 180, 100)"
# Frammento 2: "rgb(160, 170, 80)"
# Frammento 3: "rgb(140, 160, 90)"
# Frammento 4: "rgb(50, 120, 150)"
# Frammento 5: "rgb(200, 190, 110)"
# Riga CSV: ['025233.mp3', '"rgb(150, 180, 100)"', '"rgb(160, 170, 80)"', '"rgb(140, 160, 90)"', '"rgb(50, 120, 150)"', '"rgb(200, 190, 110)"']
#
# === Elaborazione canzone 96: 025234.mp3 ===
#
# Risposta generata dal modello:
#
# RGB: (120, 180, 50) (100, 150, 60) (160, 80, 40) (200, 160, 80) (180, 140, 60)
#
# ==================================================
# RGB matches trovati: 5
# Dettagli matches: [('120', '180', '50'), ('100', '150', '60'), ('160', '80', '40'), ('200', '160', '80'), ('180', '140', '60')]
# Frammento 1: "rgb(120, 180, 50)"
# Frammento 2: "rgb(100, 150, 60)"
# Frammento 3: "rgb(160, 80, 40)"
# Frammento 4: "rgb(200, 160, 80)"
# Frammento 5: "rgb(180, 140, 60)"
# Riga CSV: ['025234.mp3', '"rgb(120, 180, 50)"', '"rgb(100, 150, 60)"', '"rgb(160, 80, 40)"', '"rgb(200, 160, 80)"', '"rgb(180, 140, 60)"']
#
# === Elaborazione canzone 97: 025235.mp3 ===
#
# Risposta generata dal modello:
#
# RGB: (190, 60, 30) (50, 100, 150) (160, 180, 120) (140, 160, 100) (180, 120, 40)
#
# ==================================================
# RGB matches trovati: 5
# Dettagli matches: [('190', '60', '30'), ('50', '100', '150'), ('160', '180', '120'), ('140', '160', '100'), ('180', '120', '40')]
# Frammento 1: "rgb(190, 60, 30)"
# Frammento 2: "rgb(50, 100, 150)"
# Frammento 3: "rgb(160, 180, 120)"
# Frammento 4: "rgb(140, 160, 100)"
# Frammento 5: "rgb(180, 120, 40)"
# Riga CSV: ['025235.mp3', '"rgb(190, 60, 30)"', '"rgb(50, 100, 150)"', '"rgb(160, 180, 120)"', '"rgb(140, 160, 100)"', '"rgb(180, 120, 40)"']
#
# === Elaborazione canzone 98: 025324.mp3 ===
#
# Risposta generata dal modello:
#
# RGB: (200, 30, 30) (210, 40, 35) (190, 35, 30) (220, 45, 35) (215, 40, 30)
#
# ==================================================
# RGB matches trovati: 5
# Dettagli matches: [('200', '30', '30'), ('210', '40', '35'), ('190', '35', '30'), ('220', '45', '35'), ('215', '40', '30')]
# Frammento 1: "rgb(200, 30, 30)"
# Frammento 2: "rgb(210, 40, 35)"
# Frammento 3: "rgb(190, 35, 30)"
# Frammento 4: "rgb(220, 45, 35)"
# Frammento 5: "rgb(215, 40, 30)"
# Riga CSV: ['025324.mp3', '"rgb(200, 30, 30)"', '"rgb(210, 40, 35)"', '"rgb(190, 35, 30)"', '"rgb(220, 45, 35)"', '"rgb(215, 40, 30)"']
#
# === Elaborazione canzone 99: 025378.mp3 ===
#
# Risposta generata dal modello:
#
# RGB: (180, 50, 50) (140, 100, 60) (100, 150, 160) (190, 80, 30) (200, 120, 40)
#
# ==================================================
# RGB matches trovati: 5
# Dettagli matches: [('180', '50', '50'), ('140', '100', '60'), ('100', '150', '160'), ('190', '80', '30'), ('200', '120', '40')]
# Frammento 1: "rgb(180, 50, 50)"
# Frammento 2: "rgb(140, 100, 60)"
# Frammento 3: "rgb(100, 150, 160)"
# Frammento 4: "rgb(190, 80, 30)"
# Frammento 5: "rgb(200, 120, 40)"
# Riga CSV: ['025378.mp3', '"rgb(180, 50, 50)"', '"rgb(140, 100, 60)"', '"rgb(100, 150, 160)"', '"rgb(190, 80, 30)"', '"rgb(200, 120, 40)"']
#
# === Elaborazione canzone 100: 025601.mp3 ===
#
# Risposta generata dal modello:
#
# RGB: (100, 150, 50) (130, 160, 60) (120, 140, 55) (110, 145, 55) (125, 155, 50)
#
# ==================================================
# RGB matches trovati: 5
# Dettagli matches: [('100', '150', '50'), ('130', '160', '60'), ('120', '140', '55'), ('110', '145', '55'), ('125', '155', '50')]
# Frammento 1: "rgb(100, 150, 50)"
# Frammento 2: "rgb(130, 160, 60)"
# Frammento 3: "rgb(120, 140, 55)"
# Frammento 4: "rgb(110, 145, 55)"
# Frammento 5: "rgb(125, 155, 50)"
# Riga CSV: ['025601.mp3', '"rgb(100, 150, 50)"', '"rgb(130, 160, 60)"', '"rgb(120, 140, 55)"', '"rgb(110, 145, 55)"', '"rgb(125, 155, 50)"']
#
# === Elaborazione canzone 101: Song Name ===
#
# Risposta generata dal modello:
#
# RGB: (180, 80, 30) (200, 150, 50) (150, 100, 40) (120, 70, 20) (100, 60, 10)
#
# ==================================================
# RGB matches trovati: 5
# Dettagli matches: [('180', '80', '30'), ('200', '150', '50'), ('150', '100', '40'), ('120', '70', '20'), ('100', '60', '10')]
# Frammento 1: "rgb(180, 80, 30)"
# Frammento 2: "rgb(200, 150, 50)"
# Frammento 3: "rgb(150, 100, 40)"
# Frammento 4: "rgb(120, 70, 20)"
# Frammento 5: "rgb(100, 60, 10)"
# Riga CSV: ['Song Name', '"rgb(180, 80, 30)"', '"rgb(200, 150, 50)"', '"rgb(150, 100, 40)"', '"rgb(120, 70, 20)"', '"rgb(100, 60, 10)"']
#
# --- Salvataggio dei colori RGB in CSV ---
# Colori RGB salvati in 'valutazione_rgb_segmenti.csv'
#
# Verifica del file salvato:
# Numero di righe totali: 102
# Header: Song Name,Frammento 1,Frammento 2,Frammento 3,Frammento 4,Descrizione Totale
# Prima riga dati: 000002.mp3,"""rgb(220, 150, 30)""","""rgb(180, 120, 40)""","""rgb(200, 160, 50)""","""rgb(210, 140, 35)""","""rgb(190, 130, 45)"""
# Seconda riga dati: 000005.mp3,"""rgb(230, 165, 40)""","""rgb(210, 150, 30)""","""rgb(120, 80, 20)""","""rgb(180, 110, 30)""","""rgb(240, 120, 40)"""
#
# Processing complete. I valori RGB sono stati salvati nel file CSV.
#
# ============================================================
# ESECUZIONE VISUALIZZAZIONE
# ============================================================
#
# Sto per visualizzare i colori delle prime 3 canzoni dal file CSV generato.
# Chiudi ogni finestra per procedere alla successiva.
# Visualizzazione completata. Modifica il parametro 'max_canzoni' per vederne di più.
